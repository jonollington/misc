# %%
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/EPL 19-20 outfield openplay stats per 90_min500.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Drop columns
df = df.drop(['position', 'player', 'team', 'foot'], axis=1)

# %%
all_data_df = pd.read_csv('../data/all_data.csv', index_col=0)

# %%
from sklearn import preprocessing
data_scaled = pd.DataFrame(preprocessing.scale(df),columns = df.columns)

# %%
coefs_df = pd.read_csv('../data/coefs.csv',index_col=0)

# %%
coefs_df
# Out:
#            age   team_id  total_scoring_att  ontarget_scoring_att  \
# PC-1 -0.033337 -0.011390           0.034177              0.017240
# PC-2 -0.035766 -0.074937           0.125053              0.093007
#
#       blocked_scoring_att     goals  own_goals  post_scoring_att  total_pass  \
# PC-1             0.069993  0.003519  -0.005150         -0.000414   -0.006983
# PC-2             0.085423  0.063226   0.004338          0.039306    0.214875
#
#       accurate_pass  ...  expected_goals_lf  expected_goals_rf  \
# PC-1      -0.012821  ...           0.040492           0.009045
# PC-2       0.201705  ...           0.041035           0.062054
#
#       expected_goals_conceded  expected_goals_nonpenalty_conceded  \
# PC-1                -0.034566                           -0.037533
# PC-2                -0.133152                           -0.139624
#
#       expected_goalsontarget  expected_goalsontarget_nonpenalty  \
# PC-1                0.007292                           0.006389
# ...

# %%
# PCA
pca = PCA(n_components=2)
pca.fit_transform(data_scaled)
# Out:
# array([[-7.26811887e+00, -2.96075141e+00],
#        [-8.39774121e+00, -3.04708964e+00],
#        [-5.31681580e+00,  3.90229644e+00],
#        [ 5.69552095e+00,  1.68946824e+00],
#        [-1.28991917e+00,  8.69759760e+00],
#        [ 1.23884564e+01, -3.30297571e+00],
#        [ 1.91061396e+01, -2.68986367e+00],
#        [-1.21666193e-02,  1.85477824e+00],
#        [ 6.56350906e+00,  6.72913568e+00],
#        [-4.73352061e+00,  2.37900891e+00],
#        [-4.31030298e+00,  4.21777223e+00],
#        [-5.20430771e+00,  5.74693048e+00],
#        [ 5.09375612e+00,  1.35168050e+00],
#        [-2.07114785e+00,  1.58353244e+00],
#        [ 3.27337616e+00,  7.75794604e+00],
#        [ 1.20066425e+01, -2.48718271e+00],
#        [ 6.10029119e+00,  8.73123770e+00],
#        [ 1.07124565e+01, -3.68280798e+00],
#        [-7.87888563e+00, -2.55736113e+00],
#        [-6.71018753e+00,  2.77605659e+00],
#        [-7.72334775e+00, -4.87803695e+00],
#        [ 1.11852229e+01,  4.67110074e+00],
# ...

# %%
i = np.identity(df.shape[1])

# %%
coefs_test = coefs_df.values
coefs_test = coefs_test.reshape(-1, 2)

# %%
print(coefs_test.shape)
# Out:
# (244, 2)

# %%
all_data_test = all_data_df[['PC-1', 'PC-2']].values

# %%
all_data_test.shape
# Out:
# (133, 2)

# %% [markdown]
# ---------------------------------------------------------------

# %%
results = np.dot(coefs_test, all_data_test.reshape(2, 133)).T

# %%
final_result = pd.DataFrame(results, columns = coefs_df.columns)

# %%
final_result
# Out:
#           age   team_id  total_scoring_att  ontarget_scoring_att  \
# 0    0.048671 -0.057144          -0.075618              0.005765
# 1   -0.029889  0.024154           0.086533             -0.006186
# 2    0.034888 -0.036267          -0.071412              0.005268
# 3    0.007910 -0.015356           0.009959             -0.000531
# 4   -0.033325  0.030305           0.084110             -0.006081
# 5    0.002267  0.002722          -0.023258              0.001571
# 6   -0.025117  0.025545           0.053479             -0.003929
# 7    0.002858 -0.011093           0.023920             -0.001533
# 8   -0.036182  0.033876           0.087758             -0.006367
# 9   -0.009360  0.013283           0.006134             -0.000554
# 10  -0.029731  0.023165           0.089234             -0.006362
# 11   0.007327 -0.015025           0.012161             -0.000686
# 12   0.027633 -0.026571          -0.064456              0.004693
# ...
