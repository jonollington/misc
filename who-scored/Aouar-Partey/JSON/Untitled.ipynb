# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.patches as patches
warnings.filterwarnings("ignore")
from mplsoccer.pitch import Pitch
plt.style.use('ggplot')
from PIL import Image
from highlight_text import htext
from matplotlib import cm
import matplotlib.patheffects as path_effects

# %%
with open(r"Lyon_Toulouse.json") as f:
    md = json.load(f)

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = json_normalize(md["events"], sep="_")

# %%
df.isGoal.value_counts()
# Out:
# True    3
# Name: isGoal, dtype: int64

# %%
df.isGoal.value_counts()
# Out:
# True    3
# Name: isGoal, dtype: int64

# %%
df['Assist'] = df['isGoal'].shift(-3)

# %%
mask1 = df['Assist'] == True
df.loc[mask1]
# Out:
#       eventId  expandedMinute          id  isTouch  minute  \
# 474       308              28  2178992941     True      28
# 1291      807              74  2179031589     True      70
# 1363      845              80  2179034793    False      76
#
#                                              qualifiers  \
# 474   [{'type': {'displayName': 'RegularPlay', 'valu...
# 1291  [{'type': {'displayName': 'BlockedX', 'value':...
# 1363                                                 []
#
#                                    satisfiedEventsTypes  second  teamId     x  \
# 474   [90, 91, 118, 116, 122, 123, 126, 204, 38, 45,...     7.0     228  49.4
# 1291                               [90, 8, 9, 2, 3, 12]    41.0     228  79.9
# 1363                                               [92]     8.0     228  78.2
#
#          y outcomeType_displayName  outcomeType_value period_displayName  \
# 474   33.0              Successful                  1          FirstHalf
# 1291  68.8              Successful                  1         SecondHalf
# 1363  36.6              Successful                  1         SecondHalf
#
#       period_value type_displayName  type_value  endX  endY  playerId  \
# 474              1             Pass           1  72.0  87.4  322096.0
# 1291             2        SavedShot          15   NaN   NaN  121718.0
# 1363             2     BallRecovery          49   NaN   NaN  140090.0
#
#       goalMouthY  goalMouthZ isShot  relatedEventId  relatedPlayerId  \
# 474          NaN         NaN    NaN             NaN              NaN
# 1291        52.2        12.7   True             NaN              NaN
# 1363         NaN         NaN    NaN             NaN              NaN
#
#       blockedX  blockedY isGoal cardType_displayName  cardType_value  $idx  \
# 474        NaN       NaN    NaN                  NaN             NaN   NaN
# 1291      97.5      52.3    NaN                  NaN             NaN  16.0
# 1363       NaN       NaN    NaN                  NaN             NaN   NaN
#
#       $len  field                                         satisfiers  \
# 474    NaN    NaN                                                NaN
# 1291  20.0    1.0  [{'$idx': 0, '$len': 6, 'id': 90, 'name': 'tou...
# 1363   NaN    NaN                                                NaN
#
#                                                    text  \
# 474                                                 NaN
# 1291  Marçal has attempt saved (Low to the left, Out...
# 1363                                                NaN
#
#       minuteInfo_expandedMinute  minuteInfo_extraTime  \
# 474                         NaN                   NaN
# 1291                       74.0                   0.0
# 1363                        NaN                   NaN
#
#      minuteInfo_isEndOfPeriod minuteInfo_minute minuteInfo_minuteString  \
# 474                       NaN               NaN                     NaN
# 1291                    False                70                      71
# 1363                      NaN               NaN                     NaN
#
#      minuteInfo_period  type_$idx  type_$len Assist
# 474                NaN        NaN        NaN   True
# 1291                 2        NaN        NaN   True
# 1363               NaN        NaN        NaN   True

# %%
mask = (df['playerId'] == 322096) & (df['Assist'] == True)
aouar = df.loc[mask]
aouar
# Out:
#      eventId  expandedMinute          id  isTouch  minute  \
# 474      308              28  2178992941     True      28
#
#                                             qualifiers  \
# 474  [{'type': {'displayName': 'RegularPlay', 'valu...
#
#                                   satisfiedEventsTypes  second  teamId     x  \
# 474  [90, 91, 118, 116, 122, 123, 126, 204, 38, 45,...     7.0     228  49.4
#
#         y outcomeType_displayName  outcomeType_value period_displayName  \
# 474  33.0              Successful                  1          FirstHalf
#
#      period_value type_displayName  type_value  endX  endY  playerId  \
# 474             1             Pass           1  72.0  87.4  322096.0
#
#      goalMouthY  goalMouthZ isShot  relatedEventId  relatedPlayerId  blockedX  \
# 474         NaN         NaN    NaN             NaN              NaN       NaN
#
#      blockedY isGoal cardType_displayName  cardType_value  $idx  $len  field  \
# 474       NaN    NaN                  NaN             NaN   NaN   NaN    NaN
#
#     satisfiers text  minuteInfo_expandedMinute  minuteInfo_extraTime  \
# 474        NaN  NaN                        NaN                   NaN
#
#     minuteInfo_isEndOfPeriod minuteInfo_minute minuteInfo_minuteString  \
# 474                      NaN               NaN                     NaN
#
#     minuteInfo_period  type_$idx  type_$len Assist
# 474               NaN        NaN        NaN   True

# %%
aouar.to_csv('Lyon_Toulouse1.csv', index=False)

# %%
import os
import glob
import pandas as pd
import seaborn as sns

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "aouar_all1.csv", index=False, encoding='utf-8-sig')
