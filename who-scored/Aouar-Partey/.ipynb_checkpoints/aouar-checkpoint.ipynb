# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.patches as patches
warnings.filterwarnings("ignore")
from mplsoccer.pitch import Pitch
plt.style.use('ggplot')
from PIL import Image
from highlight_text import htext
from matplotlib import cm
import matplotlib.patheffects as path_effects

# %%
# with open(r"Amiens_Lyon.json") as f:
#     md = json.load(f)

# %%
# pd.set_option('display.max_columns', None)
# # pd.set_option('display.max_rows', None)

# %%
# df = json_normalize(md["events"], sep="_")

# %%
# md

# %%
# mask = df['playerId'] == 322096
# df = df.loc[mask]

# %%
# df.isGoal.value_counts()

# %%
# df['Assist'] = df['isGoal'].shift(-1)

# %%
# mask1 = df['Assist'] == True
# df.loc[mask1]

# %%
# mask = df['playerId'] == 13756
# mesut = df.loc[mask]

# %%
# df.to_csv('Swansea_Arsenal1.csv', index=False)

# %% [markdown]
# ________________________________________________

# %%
with open('Nimes_Lyon.json') as json_file:
    data = json.load(json_file)

event = []
minute = []
second = []
player = []
team = []
outcome = []
x = []
y = []
endX = []
endY = []
goal = []
passtype = []


for each in data['events']:
    event.append(each['type']['displayName'])
    try:
        minute.append(each['minute'])
    except:
        minute.append('')
    try:
        second.append(each['second'])
    except:
        second.append('')
    try:
        player.append(each['playerId'])
    except:
        player.append('')
    try:
        team.append(each['teamId'])
    except:
        team.append('')
    try:
        endX.append(each['endX'])
        endY.append(each['endY'])
    except:
        endX.append('')
        endY.append('')
    outcome.append(each['outcomeType']['displayName'])
    x.append(each['x'])
    y.append(each['y'])

    for key, value in each.items():
        passType = 'OpenPlay'
        if key == 'qualifiers':
            for item in value:
                if item['type']['displayName'] == 'IntentionalGoalAssist':
                    passType = item['type']['displayName']
                elif item['type']['displayName'] == 'BigChanceCreated':
                    passType = item['type']['displayName']
                elif item['type']['displayName'] == 'Assisted':
                    passType = item['type']['displayName']
            passtype.append(passType)
                
events = pd.DataFrame({'Event':event, 'Minute':minute, 'Second':second, 'Player':player, 'Team':team, 'Outcome':outcome, 'x':x, 'y':y,
                      'endX':endX, 'endY':endY, 'passtype':passtype})

# %%
events.to_csv('Nimes_Lyon.csv', index=False)

# %%
pwd
# Out:
# '/Users/ollinj01/Football Analytics/who-scored/Ozil'

# %%
mask = combined_csv['Player'] == 322096
aouar = combined_csv.loc[mask]
aouar.head()
# Out:
#                Event  Minute  Second    Player  Team       Outcome     x  \
# 1355  SubstitutionOn      85     1.0  322096.0   228    Successful   0.0
# 1391          Tackle      87    28.0  322096.0   228    Successful  39.4
# 1392          TakeOn      87    30.0  322096.0   228  Unsuccessful  42.3
# 1437            Pass      89    43.0  322096.0   228    Successful  53.8
# 1462          TakeOn      90    52.0  322096.0   228    Successful  48.4
#
#          y  endX  endY  passtype
# 1355   0.0   NaN   NaN  OpenPlay
# 1391  35.5   NaN   NaN  OpenPlay
# 1392  33.4   NaN   NaN  OpenPlay
# 1437  41.6  47.2  70.9  OpenPlay
# 1462  49.1   NaN   NaN  OpenPlay

# %%
aouar.passtype.value_counts()
# Out:
# OpenPlay                 1620
# Assisted                   35
# IntentionalGoalAssist       2
# BigChanceCreated            2
# Name: passtype, dtype: int64

# %%
mask1 = ((aouar['passtype'] == 'IntentionalGoalAssist') & ((aouar['x'] < 99.3) & (aouar['y'] < 99)))
assist = aouar.loc[mask1]
len(assist)
# Out:
# 2

# %%
mask2 = (aouar['passtype'] == 'BigChanceCreated') & ((aouar['x'] < 99) & (aouar['y'] > 1))
chance = aouar.loc[mask2]
len(chance)
# Out:
# 2

# %%
mask3 = (aouar['Event'] == 'MissedShots') | (mesut['Event'] == 'SavedShot')
shot = aouar.loc[mask3]
len(shot)
# Out:
# 40

# %%
mask4 = aouar['Event'] == 'Goal'
goals = aouar.loc[mask4]
len(goals)
# Out:
# 3

# %%
mask5 = (aouar['passtype'] == 'IntentionalGoalAssist') & ((aouar['x'] > 99) & (aouar['y'] > 99)) | (aouar['passtype'] == 'IntentionalGoalAssist') & ((aouar['x'] > 99) & (aouar['y'] < 1)) & ((aouar['x'] > 99) & (aouar['y'] < 1))
corner = aouar.loc[mask5]
len(corner)
# Out:
# 0

# %%
mask5 = (aouar['passtype'] == 'BigChanceCreated') & ((aouar['x'] > 99) & (aouar['y'] < 1))
corner1 = aouar.loc[mask5]
corner1
# Out:
# Empty DataFrame
# Columns: [Event, Minute, Second, Player, Team, Outcome, x, y, endX, endY, passtype]
# Index: []

# %%
mask5 = (aouar['passtype'] != 'IntentionalGoalAssist') & (aouar['passtype'] != 'BigChanceCreated') & (aouar['x'] < 99) & (aouar['y'] < 99) & ((aouar['x'] > 1) & (aouar['y'] > 1)) & ((aouar['y'] != 50.3) & (aouar['x'] != 50.7)) & (aouar['x'] != 50.9) & (aouar['y'] != 50.1) & (aouar['y'] != 50.0)
touch = aouar.loc[mask5]

# %%
# mesut["endX"] = pd.to_numeric(events["endX"])
# mesut["endY"] = pd.to_numeric(events["endY"])

# %%
background = "#313332"
line = '#696969'
text_color ='white'
touches = '#f62681'
assisted = "#45c7e8"
assisted1= '#308BA2'
goal = '#59c08a'
title_font = "BBC Reith Sans"
body_font = "BBC Reith Sans"

pitch = Pitch(figsize=(15,15),orientation='horizontal',view='full',goal_type='box',pitch_type='opta',
              pitch_color=background, line_color=line,constrained_layout=False)

fig, ax = pitch.draw()

#touches
x = touch.x.values
y = touch.y.values
ax.scatter(x,y,color='white', s=150, zorder=12, alpha=0.02)

#assists
style="wedge,tail_width=0.4"
xA = assist.x.values
yA = assist.y.values
xEA = assist.endX.values
yEA = assist.endY.values

plt.scatter(xEA,yEA,color=assisted, s=150, ec=background, lw=1.5,zorder=14, alpha=0.7)

for i in range(len(assist)):
    plt.annotate('', xy=(xA[i],yA[i]), xytext=(xEA[i],yEA[i]), zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))
    
#corner
xC = corner.endX.values
yC = corner.endY.values

plt.scatter(xC,yC,color=assisted, s=150, ec=background, lw=1.5,zorder=13, alpha=0.7)

#cornerbcc
xCC = corner1.endX.values
yCC = corner1.endY.values

plt.scatter(xCC,yCC,c=background,ec=assisted,lw=1.5, s=130, zorder=12, alpha=0.7)

#chances created
xC = chance.x.values
yC = chance.y.values
xEC = chance.endX.values
yEC = chance.endY.values
plt.scatter(xEC,yEC,c=background, ec=assisted,lw=1.5, s=130, zorder=12, alpha=0.6)

for i in range(len(chance)):
    plt.annotate('', xy=(xC[i],yC[i]), xytext=(xEC[i],yEC[i]), zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))
    
#shots
xS = shot.x.values
yS = shot.y.values

plt.scatter(xS,yS,color=background, ec=goal, lw=1.5, s=130, zorder=11, alpha=0.6)

#goals
xG = goals.x.values
yG = goals.y.values
plt.scatter(xG,yG,color=goal, ec=background, lw=1, s=150, zorder=13, alpha=0.9)

fig.text(0.035, 0.943, "Houssem Aouar",fontsize=35, fontfamily=body_font, color=text_color, weight='bold',zorder=2)
fig.text(0.035, 0.923, "Olympique Lyonnais | Ligue 1 | Season 2019/2020",fontsize=20, fontfamily=body_font, color=text_color,zorder=2)
# fig.text(0.035, 0.96, "n",fontsize=20,color=background,zorder=1)
# n = fig.text(0.925, 0.866, "Mesut Özil",fontsize=19, fontfamily=body_font, color=background,zorder=2, ha='center')
# fig.text(0.88, 0.833, "How well did                           \ncompare in P90 goal\ncontributions?",fontsize=16, fontfamily=body_font, color=text_color,zorder=2, ha='center')

n.set_path_effects([path_effects.withStroke(linewidth=4,foreground=assisted)])

# ax2 = fig.add_axes([0.005,0.803,0.8,0.12]) # beeswarm

# ax2.patch.set_facecolor(background)
# plt.sca(ax2)
# sns.swarmplot(x=cont["G+A"],color='silver',zorder=1,alpha=1, size=6)
# sns.swarmplot(x=ozil["G+A"],color=background,ec=assisted,linewidth=4,zorder=1, size=15)
# plt.axis('off')

# ax2 = fig.add_axes([0.9,0.90,0.075,0.075]) # badge
# ax2.axis("off")
# img = Image.open('./Arsenal.png')
# ax2.imshow(img)

ax3 = fig.add_axes([0.02,0.17,0.05,0.02])
ax3.axis("off")
ax3.scatter([0.02],[0.05],c='white', s=200, zorder=12, alpha=0.1)
fig.text(0.057, 0.175, "all passes",fontsize=15, fontfamily=body_font, color=text_color)

ax4 = fig.add_axes([0.135,0.17,0.05,0.02])
ax4.axis("off")
ax4.scatter([0.135],[0.05],ec=goal, c=background, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.171, 0.175, "shot",fontsize=15, fontfamily=body_font, color=text_color)

ax5 = fig.add_axes([0.216,0.17,0.05,0.02])
ax5.axis("off")
ax5.scatter([0.216],[0.05],c=goal, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.253, 0.175, "goal",fontsize=15, fontfamily=body_font, color=text_color)

ax6 = fig.add_axes([0.3,0.17,0.05,0.02])
ax6.axis("off")
ax6.annotate('', [0.3,0.5],[1.5,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color=assisted, shrinkA=6, alpha=0.6))

ax7 = fig.add_axes([0.35,0.17,0.05,0.02])
ax7.axis("off")
ax7.scatter([0.35],[0.05],ec=assisted, c=background, s=200, linewidth=1.5, zorder=12, alpha=0.9)
fig.text(0.387, 0.175, "big chance created",fontsize=15, fontfamily=body_font, color=text_color)

ax8 = fig.add_axes([0.52,0.17,0.05,0.02])
ax8.axis("off")
ax8.annotate('', [0.52,0.5],[1.5,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color=assisted, shrinkA=6, alpha=0.6))

ax9 = fig.add_axes([0.573,0.17,0.05,0.02])
ax9.axis("off")
ax9.scatter([0.573],[0.05], c=assisted, s=200, linewidth=1.5, zorder=12, alpha=0.9)
fig.text(0.609, 0.175, "assist",fontsize=15, fontfamily=body_font, color=text_color)

fig.text(0.86, 0.175, "@jonollington",fontsize=17, fontfamily=body_font, color=text_color)

plt.rcParams['axes.facecolor']=background
plt.rcParams['savefig.facecolor']=background
plt.savefig("aouar",bbox_inches="tight",dpi=300);

# %%
# import os
# import glob
# import pandas as pd
# import seaborn as sns

# %%
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "aouar_all.csv", index=False, encoding='utf-8-sig')

# %%
cont = pd.read_html('https://fbref.com/en/comps/Big5/2015-2016/stats/players/2015-2016-Big-5-European-Leagues-Stats')[0]

# %%
def drop_header(df):
    my_df = df.copy()
    my_df = my_df.droplevel(0, axis=1)
    return(my_df)

# %%
cont = drop_header(cont)

# %%
def cleaner(df):
    all_columns = list(df.columns)
    unwanted_columns = {'Player','Comp'}
    index_columns = [ele for ele in all_columns if ele not in unwanted_columns]
#     num_df = df.loc[:,index_columns].apply(pd.to_numeric, errors='coerce')
    num_df.fillna(0, inplace=True)
    master_df = pd.concat([df[['Player', 'Comp']], num_df], axis = 1)
    return master_df

# %%
mask = (cont['Comp'] == 'eng Premier League') & (cont['G+A'] > '0')
cont = cont.loc[mask]

# %%
mask2=(cont['Player']=='Mesut Özil')
ozil=cont[mask2]
ozil
# Out:
#         Rk      Player  Nation Pos    Squad                Comp Age  Born  MP  \
# 2033  1956  Mesut Özil  de GER  MF  Arsenal  eng Premier League  26  1988  35
#
#      Starts   Min Gls Ast PK PKatt CrdY CrdR   Gls   Ast   G+A  G-PK G+A-PK  \
# 2033     35  3035   6  19  0     0    4    0  0.18  0.56  0.74  0.18   0.74
#
#       Matches
# 2033  Matches

# %%
# combined = pd.read_csv('./aouar_all.csv')

# %% [markdown]
# _________________________________________________

# %%
mask = combined_csv['Player'] == 322096
aouar = combined_csv.loc[mask]
aouar.head()
# Out:
#                Event  Minute  Second    Player  Team       Outcome     x  \
# 1355  SubstitutionOn      85     1.0  322096.0   228    Successful   0.0
# 1391          Tackle      87    28.0  322096.0   228    Successful  39.4
# 1392          TakeOn      87    30.0  322096.0   228  Unsuccessful  42.3
# 1437            Pass      89    43.0  322096.0   228    Successful  53.8
# 1462          TakeOn      90    52.0  322096.0   228    Successful  48.4
#
#          y  endX  endY  passtype
# 1355   0.0   NaN   NaN  OpenPlay
# 1391  35.5   NaN   NaN  OpenPlay
# 1392  33.4   NaN   NaN  OpenPlay
# 1437  41.6  47.2  70.9  OpenPlay
# 1462  49.1   NaN   NaN  OpenPlay

# %%
#calculate pass distance
aouar['dist'] = np.sqrt( (aouar.endX-aouar.x)**2 + (aouar.endY-aouar.y)**2)

# %%
aouar.dtypes
# Out:
# Event        object
# Minute        int64
# Second      float64
# Player      float64
# Team          int64
# Outcome      object
# x           float64
# y           float64
# endX        float64
# endY        float64
# passtype     object
# dist        float64
# dtype: object

# %%
#calculate progressive passes 10 meters
pt =  (aouar['dist'] > 26) & (aouar['Outcome'] == 'Successful') & (aouar['endX'] > aouar['x'])
prog10=aouar.loc[pt]
len(prog10)
# Out:
# 111

# %%
background = "#313332"
line = '#696969'
text_color ='white'
touches = '#f62681'
assisted = "#45c7e8"
assisted1= '#308BA2'
goal = '#59c08a'
title_font = "BBC Reith Sans"
body_font = "BBC Reith Sans"

pitch = Pitch(figsize=(15,15),orientation='horizontal',view='full',goal_type='box',pitch_type='opta',
              axis=True, label=True, pitch_color=background, line_color=line,constrained_layout=False)

fig, ax = pitch.draw()

#touches
x = touch.x.values
y = touch.y.values
ax.scatter(x,y,color='white', s=150, zorder=12, alpha=0.02)

#progressive passes
style="wedge,tail_width=0.4"
xA = prog10.x.values
yA = prog10.y.values
xEA = prog10.endX.values
yEA = prog10.endY.values

plt.scatter(xEA,yEA,color=assisted, s=150, ec=background, lw=1.5,zorder=14, alpha=0.7)

for i in range(len(prog10)):
    plt.annotate('', xy=(xA[i],yA[i]), xytext=(xEA[i],yEA[i]), zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))
    
# #corner
# xC = corner.endX.values
# yC = corner.endY.values

# plt.scatter(xC,yC,color=assisted, s=150, ec=background, lw=1.5,zorder=13, alpha=0.7)

# #cornerbcc
# xCC = corner1.endX.values
# yCC = corner1.endY.values

# plt.scatter(xCC,yCC,c=background,ec=assisted,lw=1.5, s=130, zorder=12, alpha=0.7)

# #chances created
# xC = chance.x.values
# yC = chance.y.values
# xEC = chance.endX.values
# yEC = chance.endY.values
# plt.scatter(xEC,yEC,c=background, ec=assisted,lw=1.5, s=130, zorder=12, alpha=0.6)

# for i in range(len(chance)):
#     plt.annotate('', xy=(xC[i],yC[i]), xytext=(xEC[i],yEC[i]), zorder=7, arrowprops=dict(arrowstyle=style,
#             linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))
    
#shots
xS = shot.x.values
yS = shot.y.values

plt.scatter(xS,yS,color=background, ec=goal, lw=1.5, s=130, zorder=11, alpha=0.6)

#goals
xG = goals.x.values
yG = goals.y.values
plt.scatter(xG,yG,color=goal, ec=background, lw=1, s=150, zorder=13, alpha=0.9)

fig.text(0.035, 0.943, "Houssem Aouar",fontsize=35, fontfamily=body_font, color=text_color, weight='bold',zorder=2)
fig.text(0.035, 0.923, "Olympique Lyonnais | Ligue 1 | Season 2019/2020",fontsize=20, fontfamily=body_font, color=text_color,zorder=2)
# fig.text(0.035, 0.96, "n",fontsize=20,color=background,zorder=1)
# n = fig.text(0.925, 0.866, "Mesut Özil",fontsize=19, fontfamily=body_font, color=background,zorder=2, ha='center')
# fig.text(0.88, 0.833, "How well did                           \ncompare in P90 goal\ncontributions?",fontsize=16, fontfamily=body_font, color=text_color,zorder=2, ha='center')

n.set_path_effects([path_effects.withStroke(linewidth=4,foreground=assisted)])

# ax2 = fig.add_axes([0.005,0.803,0.8,0.12]) # beeswarm

# ax2.patch.set_facecolor(background)
# plt.sca(ax2)
# sns.swarmplot(x=cont["G+A"],color='silver',zorder=1,alpha=1, size=6)
# sns.swarmplot(x=ozil["G+A"],color=background,ec=assisted,linewidth=4,zorder=1, size=15)
# plt.axis('off')

# ax2 = fig.add_axes([0.9,0.90,0.075,0.075]) # badge
# ax2.axis("off")
# img = Image.open('./Arsenal.png')
# ax2.imshow(img)


plt.scatter([100],[50],color="pink", s=200)

ax3 = fig.add_axes([0.02,0.17,0.05,0.02])
ax3.axis("off")
ax3.scatter([0.02],[0.05],c='white', s=200, zorder=12, alpha=0.1)
fig.text(0.057, 0.175, "all passes",fontsize=15, fontfamily=body_font, color=text_color)

ax4 = fig.add_axes([0.135,0.17,0.05,0.02])
ax4.axis("off")
ax4.scatter([0.135],[0.05],ec=goal, c=background, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.171, 0.175, "shot",fontsize=15, fontfamily=body_font, color=text_color)

ax5 = fig.add_axes([0.216,0.17,0.05,0.02])
ax5.axis("off")
ax5.scatter([0.216],[0.05],c=goal, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.253, 0.175, "goal",fontsize=15, fontfamily=body_font, color=text_color)

ax6 = fig.add_axes([0.3,0.17,0.05,0.02])
ax6.axis("off")
ax6.annotate('', [0.3,0.5],[1.5,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color=assisted, shrinkA=6, alpha=0.6))

ax7 = fig.add_axes([0.35,0.17,0.05,0.02])
ax7.axis("off")
ax7.scatter([0.35],[0.05],ec=assisted, c=background, s=200, linewidth=1.5, zorder=12, alpha=0.9)
fig.text(0.387, 0.175, "big chance created",fontsize=15, fontfamily=body_font, color=text_color)

ax8 = fig.add_axes([0.52,0.17,0.05,0.02])
ax8.axis("off")
ax8.annotate('', [0.52,0.5],[1.5,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color=assisted, shrinkA=6, alpha=0.6))

ax9 = fig.add_axes([0.573,0.17,0.05,0.02])
ax9.axis("off")
ax9.scatter([0.573],[0.05], c=assisted, s=200, linewidth=1.5, zorder=12, alpha=0.9)
fig.text(0.609, 0.175, "assist",fontsize=15, fontfamily=body_font, color=text_color)

fig.text(0.86, 0.175, "@jonollington",fontsize=17, fontfamily=body_font, color=text_color)

plt.rcParams['axes.facecolor']=background
plt.rcParams['savefig.facecolor']=background
plt.savefig("aouar_prog",bbox_inches="tight",dpi=300);

# %%
aouar
# Out:
#                Event  Minute  Second    Player  Team       Outcome     x  \
# 1355  SubstitutionOn      85     1.0  322096.0   228    Successful   0.0
# 1391          Tackle      87    28.0  322096.0   228    Successful  39.4
# 1392          TakeOn      87    30.0  322096.0   228  Unsuccessful  42.3
# 1437            Pass      89    43.0  322096.0   228    Successful  53.8
# 1462          TakeOn      90    52.0  322096.0   228    Successful  48.4
# ...              ...     ...     ...       ...   ...           ...   ...
# 1491            Pass      84    37.0  322096.0   228    Successful  27.3
# 1516          TakeOn      86    19.0  322096.0   228    Successful  72.6
# 1517     MissedShots      86    22.0  322096.0   228    Successful  81.7
# 1576            Pass      92    16.0  322096.0   228  Unsuccessful  73.7
# 1607       BallTouch      93    27.0  322096.0   228  Unsuccessful  55.0
#
#          y  endX  endY  passtype       dist
# 1355   0.0   NaN   NaN  OpenPlay        NaN
# 1391  35.5   NaN   NaN  OpenPlay        NaN
# 1392  33.4   NaN   NaN  OpenPlay        NaN
# 1437  41.6  47.2  70.9  OpenPlay  30.034147
# 1462  49.1   NaN   NaN  OpenPlay        NaN
# ...    ...   ...   ...       ...        ...
# 1491  92.4  28.0  75.6  OpenPlay  16.814577
# 1516  75.8   NaN   NaN  OpenPlay        NaN
# 1517  55.7   NaN   NaN  Assisted        NaN
# 1576  92.7  88.6  67.5  OpenPlay  29.275416
# 1607  74.8   NaN   NaN  OpenPlay        NaN
#
# [1659 rows x 12 columns]

# %%
#calculate pass distance
aouar['dist'] = np.sqrt( (aouar.endX-aouar.x)**2 + (aouar.endY-aouar.y)**2)

# %%
goal_x = [100,100]

# %%
goal_y = [55,45]

# %%
aouar['end_dist'] = np.sqrt( (aouar.endX-50)**2 + (aouar.endY-100)**2)

# %%
aouar['start_dist'] = np.sqrt( (aouar.x-50)**2 + (aouar.y-100)**2)

# %%
aouar['prog_pass'] = aouar['end_dist'] - aouar['start_dist']

# %%
aouar
# Out:
#                Event  Minute  Second    Player  Team       Outcome     x  \
# 1355  SubstitutionOn      85     1.0  322096.0   228    Successful   0.0
# 1391          Tackle      87    28.0  322096.0   228    Successful  39.4
# 1392          TakeOn      87    30.0  322096.0   228  Unsuccessful  42.3
# 1437            Pass      89    43.0  322096.0   228    Successful  53.8
# 1462          TakeOn      90    52.0  322096.0   228    Successful  48.4
# ...              ...     ...     ...       ...   ...           ...   ...
# 1491            Pass      84    37.0  322096.0   228    Successful  27.3
# 1516          TakeOn      86    19.0  322096.0   228    Successful  72.6
# 1517     MissedShots      86    22.0  322096.0   228    Successful  81.7
# 1576            Pass      92    16.0  322096.0   228  Unsuccessful  73.7
# 1607       BallTouch      93    27.0  322096.0   228  Unsuccessful  55.0
#
#          y  endX  endY  passtype       dist   end_dist  start_dist  prog_pass
# 1355   0.0   NaN   NaN  OpenPlay        NaN        NaN  111.803399        NaN
# 1391  35.5   NaN   NaN  OpenPlay        NaN        NaN   65.365205        NaN
# 1392  33.4   NaN   NaN  OpenPlay        NaN        NaN   67.043643        NaN
# 1437  41.6  47.2  70.9  OpenPlay  30.034147  29.234398   58.523500 -29.289102
# 1462  49.1   NaN   NaN  OpenPlay        NaN        NaN   50.925141        NaN
# ...    ...   ...   ...       ...        ...        ...         ...        ...
# 1491  92.4  28.0  75.6  OpenPlay  16.814577  32.853615   23.938463   8.915152
# 1516  75.8   NaN   NaN  OpenPlay        NaN        NaN   33.111931        NaN
# 1517  55.7   NaN   NaN  Assisted        NaN        NaN   54.473663        NaN
# 1576  92.7  88.6  67.5  OpenPlay  29.275416  50.459984   24.798790  25.661194
# 1607  74.8   NaN   NaN  OpenPlay        NaN        NaN   25.691244        NaN
#
# [1659 rows x 15 columns]

# %%
#Left 6-yard Box
plt.plot([100,100],[55,45],color="pink")
