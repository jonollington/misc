# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.patches as patches

# %matplotlib inline

# %%
df = pd.read_csv('./fbref/defence_1920.csv')
pd.set_option('display.max_columns', None)

# %%
# Remove non-numerical data
all_columns = list(df.columns)
unwanted_columns = {'Rk','Player', 'Nation','Pos', 'Squad', 'Comp', 'Age','Born','90s'}
index_columns = [ele for ele in all_columns if ele not in unwanted_columns]

# %%
df1 = df.apply(pd.to_numeric, errors='coerce')

# %%
dfP90 = df1.loc[:,index_columns].div(df1['90s'], axis=0)

# %%
dfP90.fillna(0, inplace=True)

# %%
# P90 Dataframe
master_df = pd.concat([df[['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Born', '90s']], dfP90], axis = 1)
master_df.head()
# Out:
#                 Player   Nation    Pos           Squad                Comp  \
# 0  Patrick van Aanholt   nl NED     DF  Crystal Palace  eng Premier League
# 1           Max Aarons  eng ENG     DF    Norwich City  eng Premier League
# 2     Yunis Abdelhamid   ma MAR     DF           Reims          fr Ligue 1
# 3   Suleiman Abdullahi   ng NGA  FW,MF    Union Berlin       de Bundesliga
# 4          Mehdi Abeid   dz ALG     MF          Nantes          fr Ligue 1
#
#   Age  Born   90s       Tkl      TklW   Def 3rd   Mid 3rd   Att 3rd     Tkl.1  \
# 0  28  1990  27.9  1.827957  1.146953  1.182796  0.573477  0.071685  0.788530
# 1  19  2000  36.0  1.777778  1.000000  1.111111  0.472222  0.194444  0.583333
# 2  31  1987  28.0  2.178571  1.321429  1.535714  0.571429  0.071429  0.500000
# 3  22  1996   1.7  0.588235  0.588235  0.588235  0.000000  0.000000  0.588235
# 4  26  1992  20.2  2.970297  2.029703  1.188119  1.683168  0.099010  1.188119
#
# ...

# %%
master_df['90s'] = master_df['90s'].apply(pd.to_numeric, errors='coerce')

# %%
master_df['Age'] = master_df['Age'].apply(pd.to_numeric, errors='coerce')

# %%
mask=((master_df['Pos'] != 'DF') & ((master_df['Pos'] != 'GK')) & (master_df['Age'] >= 27)) & (master_df['Player'] != 'Moanes Dabour') &(master_df['Player']!='Ki Sung-yueng')
master_df = master_df[mask]
master_df
# Out:
#                       Player   Nation    Pos            Squad  \
# 8               Amir Abrashi   al ALB     MF         Freiburg
# 19              Aritz Aduriz   es ESP     FW    Athletic Club
# 27             Sergio Agüero   ar ARG     FW  Manchester City
# 29    Emmanuel Agyemang-Badu   gh GHA  MF,FW    Hellas Verona
# 48           Marc Albrighton  eng ENG  MF,DF   Leicester City
# ...                      ...      ...    ...              ...
# 2822     Matthias Zimmermann   de GER  DF,MF       Düsseldorf
# 2829            Ben Zolinski   de GER  FW,MF     Paderborn 07
# 2832            Steven Zuber   ch SUI  DF,FW       Hoffenheim
# 2838          David Zurutuza   es ESP     MF    Real Sociedad
# 2840           Filip Đuričić   rs SRB  MF,FW         Sassuolo
#
#                     Comp   Age  Born   90s       Gls        Sh       SoT  \
# 8          de Bundesliga  29.0  1990   7.4  0.000000  0.675676  0.270270
# ...

# %%
# Drop columns
df1 = master_df.drop(['Player', 'Nation','Pos', 'Squad', 'Comp', 'Age', 'Born', '90s'], axis=1)

# %%
# #standardise data
# normalized_df=(df1-df1.mean())/df1.std()

# %%
#Normalize data
DFNom = df1.transform(lambda x: (x - x.min())/ (x.max() - x.min()))

# %%
master_df = pd.concat([master_df[['Player','Pos','Squad','Comp','Age']], DFNom], axis = 1)
len(master_df)
# Out:
# 577

# %%
mask1=(master_df['Player']=='Willian')
willian=master_df[mask1]
willian
# Out:
#        Player Pos    Squad                Comp   Age       Gls        Sh  \
# 2772  Willian  FW  Chelsea  eng Premier League  30.0  0.242215  0.202855
#
#            SoT      G/Sh        xG  Pass 1/3       Ast     CrsPA        KP  \
# 2772  0.209919  0.008808  0.182699  0.245675  0.181661  0.232526  0.429931
#
#       Long Att  Long Cmp  Long Cmp%  Medium Att  Medium Cmp  Medium Cmp%  \
# 2772  0.383506  0.362772   0.002152    0.536923    0.491594     0.002972
#
#            PPA  passPrgDist  passProg  Short Att  Short Cmp  Short Cmp%  \
# 2772  0.483844     0.383429  0.392388   0.249135   0.100346    0.001394
#
#        TotDist        xA  BP Other       Crs    Ground      Head      High  \
# 2772  0.442779  0.386887  0.008651  0.432526  0.472809  0.170704  0.446042
#
#           Left      Live       Low  Pass Pressed     Right        Sw  \
# 2772  0.077862  0.550624  0.370092      0.391003  0.565962  0.404289
#
# ...

# %%
mask2=(master_df['Player']=='Lorenzo Insigne')
insigne=master_df[mask2]
insigne
# Out:
#                Player    Pos   Squad        Comp   Age      Gls        Sh  \
# 1205  Lorenzo Insigne  FW,MF  Napoli  it Serie A  28.0  0.19943  0.325321
#
#            SoT      G/Sh        xG  Pass 1/3       Ast     CrsPA        KP  \
# 1205  0.284188  0.003497  0.305556  0.275641  0.144231  0.161538  0.471154
#
#       Long Att  Long Cmp  Long Cmp%  Medium Att  Medium Cmp  Medium Cmp%  \
# 1205   0.31161  0.299446   0.002022     0.59866    0.563326      0.00283
#
#            PPA  passPrgDist  passProg  Short Att  Short Cmp  Short Cmp%  \
# 1205  0.388859     0.382394  0.336538   0.240385   0.092949     0.00124
#
#        TotDist        xA  BP Other       Crs    Ground      Head      High  \
# 1205  0.443038  0.368754  0.014423  0.270147  0.513856  0.128205  0.390625
#
#           Left      Live       Low  Pass Pressed     Right        Sw       TB  \
# 1205  0.042039  0.577271  0.359532      0.340812  0.621738  0.274014  0.14984
#
# ...

# %%
mask3=(master_df['Player']=='Ivan Perišić')
perisic=master_df[mask3]
perisic
# Out:
#             Player    Pos          Squad           Comp   Age       Gls  \
# 2032  Ivan Perišić  FW,MF  Bayern Munich  de Bundesliga  30.0  0.232172
#
#             Sh       SoT      G/Sh        xG  Pass 1/3      Ast     CrsPA  \
# 2032  0.267724  0.208955  0.027137  0.202488  0.164179  0.16791  0.459701
#
#             KP  Long Att  Long Cmp  Long Cmp%  Medium Att  Medium Cmp  \
# 2032  0.261194  0.275705  0.239767   0.004261    0.467709    0.395673
#
#       Medium Cmp%       PPA  passPrgDist  passProg  Short Att  Short Cmp  \
# 2032     0.005925  0.368299     0.324215  0.286567   0.320896   0.074627
#
#       Short Cmp%   TotDist        xA  BP Other       Crs    Ground      Head  \
# 2032    0.001739  0.320017  0.278135  0.033582  0.399787  0.349671  0.447761
#
#           High      Left      Live       Low  Pass Pressed     Right  \
# 2032  0.409282  0.191274  0.483452  0.470474      0.353234  0.298174
#
# ...

# %%
mask4=(master_df['Player']=='Érik Lamela')
lamela=master_df[mask4]

# %%
lamela
# Out:
#            Player    Pos      Squad                Comp   Age       Gls  \
# 1408  Érik Lamela  MF,FW  Tottenham  eng Premier League  27.0  0.115226
#
#             Sh       SoT      G/Sh        xG  Pass 1/3       Ast     CrsPA  \
# 1408  0.187963  0.138272  0.018855  0.146667       0.2  0.055556  0.041481
#
#            KP  Long Att  Long Cmp  Long Cmp%  Medium Att  Medium Cmp  \
# 1408  0.22037  0.236626  0.200413   0.004126    0.444901    0.417695
#
#       Medium Cmp%       PPA  passPrgDist  passProg  Short Att  Short Cmp  \
# 1408     0.006526  0.289411     0.224554  0.226667   0.325926   0.148148
#
#       Short Cmp%   TotDist        xA  BP Other       Crs    Ground      Head  \
# 1408     0.00337  0.306586  0.192052  0.025926  0.259259  0.404302  0.128395
#
#           High      Left      Live       Low  Pass Pressed     Right       Sw  \
# 1408  0.305556  0.461718  0.435588  0.247987      0.353086  0.050967  0.25331
#
# ...

# %%
master_df.sort_values('PrgDist', ascending=False).head()
# Out:
#              Player    Pos       Squad        Comp   Age       Gls        Sh  \
# 1851         Neymar  MF,FW   Paris S-G  fr Ligue 1  27.0  0.692542  0.383562
# 1017     Papu Gómez  MF,FW    Atalanta  it Serie A  31.0  0.172293  0.265823
# 2181  Franck Ribéry     FW  Fiorentina  it Serie A  36.0  0.148620  0.139331
# 2033  Diego Perotti  FW,MF        Roma  it Serie A  31.0  0.400916  0.099227
# 1714   Lionel Messi  FW,MF   Barcelona  es La Liga  32.0  0.607639  0.421094
#
#            SoT      G/Sh        xG  Pass 1/3       Ast     CrsPA        KP  \
# 1851  0.495434  0.034869  0.637900  0.753425  0.308219  0.230137  0.467466
# 1017  0.302743  0.008055  0.199578  0.471519  0.379747  0.407595  0.587025
# 2181  0.193206  0.027794  0.135456  0.426752  0.143312  0.142675  0.412420
# 2033  0.096220  0.033739  0.302405  0.237113  0.231959  0.115464  0.414948
# 1714  0.459375  0.014773  0.440000  0.650000  0.468750  0.105000  0.470312
#
# ...

# %%
master_df = master_df.replace(0, np.nan)
master_df
# Out:
#                       Player    Pos            Squad                Comp  \
# 8               Amir Abrashi     MF         Freiburg       de Bundesliga
# 19              Aritz Aduriz     FW    Athletic Club          es La Liga
# 27             Sergio Agüero     FW  Manchester City  eng Premier League
# 29    Emmanuel Agyemang-Badu  MF,FW    Hellas Verona          it Serie A
# 48           Marc Albrighton  MF,DF   Leicester City  eng Premier League
# ...                      ...    ...              ...                 ...
# 2822     Matthias Zimmermann  DF,MF       Düsseldorf       de Bundesliga
# 2829            Ben Zolinski  FW,MF     Paderborn 07       de Bundesliga
# 2832            Steven Zuber  DF,FW       Hoffenheim       de Bundesliga
# 2838          David Zurutuza     MF    Real Sociedad          es La Liga
# 2840           Filip Đuričić  MF,FW         Sassuolo          it Serie A
#
#        Age       Gls        Sh       SoT      G/Sh        xG  Pass 1/3  \
# ...

# %%
fig, axarr = plt.subplots(5,1, figsize=(17,14))

plt.rcParams['font.family'] = 'BBC Reith Sans'
csfont = {'fontname':'BBC Reith Sans'}
hfont = {'fontname':'BBC Reith Sans'}

#set figure background colour
fig.set_facecolor('#1a1d2c')

fig.text(0.11,0.92,"Statistically similar alternative signings to Willian",color="White",fontsize=25, **csfont, fontweight='bold')
fig.text(0.83,0.92,"@jonollington",color="White",fontsize=12, **csfont, fontweight='bold')
fig.text(0.11,0.90,"Big 5 European Leagues | Season 2019-20",color="White",fontsize=14, **csfont)
fig.text(0.11,0.075,"Excludes goalkeepers, defenders & players with < 1,000 mins",color="darkgrey",fontsize=10, **csfont, fontstyle="italic")
fig.text(0.81,0.073,"Data: FBRef | StatsBomb",color="darkgrey",fontsize=10, **csfont)

axarr[0].patch.set_facecolor('#1a1d2c')
plt.sca(axarr[0])
sns.swarmplot(x=master_df["PrgDist"],color='white',zorder=1,alpha=0.5, size=6)
sns.swarmplot(x=willian["PrgDist"],color='firebrick',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=insigne["PrgDist"],color='#12A0D7',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=perisic["PrgDist"],color='seagreen',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=lamela["PrgDist"],color='white',edgecolor='#132257',linewidth=1,zorder=1, size=13)
plt.axis('off')

axarr[0].text(0.67, -0.1, 'Willian', color='firebrick', fontsize=15,fontweight='bold',**csfont)
axarr[0].text(0.62, 0.16, 'Insigne', color='#12A0D7', fontsize=15,fontweight='bold',**csfont)
axarr[0].text(0.36, 0.3, 'Perišić', color='seagreen', fontsize=15,fontweight='bold',**csfont)
axarr[0].text(0.54, -0.13, 'Lamela', color='white', fontsize=15,fontweight='bold',**csfont)

axarr[0].text(-0.03, 0, "Progressive\nDist. Carries", rotation=90, ha='center',va='center', color="white", **csfont, fontsize=20, fontweight="bold")

axarr[1].patch.set_facecolor('#1a1d2c')
plt.sca(axarr[1])
sns.swarmplot(x=master_df["PPA"],color='white',zorder=1,alpha=0.5, size=6)
sns.swarmplot(x=willian["PPA"],color='firebrick',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=insigne["PPA"],color='#12A0D7',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=perisic["PPA"],color='seagreen',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=lamela["PPA"],color='white',edgecolor='#132257',linewidth=1,zorder=1, size=13)
plt.axis('off')

axarr[1].text(0.46, -0.1, 'Willian', color='firebrick', fontsize=15,fontweight='bold',**csfont)
axarr[1].text(0.38, -0.15, 'Insigne', color='#12A0D7', fontsize=15,fontweight='bold',**csfont)
axarr[1].text(0.36, 0.24, 'Perišić', color='seagreen', fontsize=15,fontweight='bold',**csfont)
axarr[1].text(0.26, -0.25, 'Lamela', color='white', fontsize=15,fontweight='bold',**csfont)


axarr[1].text(-0.03, 0, "Passes into\nPenalty Area", rotation=90, ha='center',va='center', color="white", **csfont, fontsize=20, fontweight="bold")

axarr[2].patch.set_facecolor('#1a1d2c')
plt.sca(axarr[2])
sns.swarmplot(x=master_df["xA"],color='white',zorder=1,alpha=0.5, size=6)
sns.swarmplot(x=willian["xA"],color='firebrick',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=insigne["xA"],color='#12A0D7',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=perisic["xA"],color='seagreen',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=lamela["xA"],color='white',edgecolor='#132257',linewidth=1,zorder=1, size=13)
plt.axis('off')

axarr[2].text(-0.03, 0, "Expected\nAssists", rotation=90, ha='center',va='center', color="white", **csfont, fontsize=20, fontweight="bold")
axarr[2].text(0.39, -0.1, 'Willian', color='firebrick', fontsize=15,fontweight='bold',**csfont)
axarr[2].text(0.37, 0.22, 'Insigne', color='#12A0D7', fontsize=15,fontweight='bold',**csfont)
axarr[2].text(0.27, 0.36, 'Perišić', color='seagreen', fontsize=15,fontweight='bold',**csfont)
axarr[2].text(0.19, -0.3, 'Lamela', color='white', fontsize=15,fontweight='bold',**csfont)

axarr[3].patch.set_facecolor('#1a1d2c')
plt.sca(axarr[3])
sns.swarmplot(x=master_df["KP"],color='white',zorder=1,alpha=0.5, size=6)
sns.swarmplot(x=willian["KP"],color='firebrick',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=insigne["KP"],color='#12A0D7',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=perisic["KP"],color='seagreen',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=lamela["KP"],color='white',edgecolor='#132257',linewidth=1,zorder=1, size=13)
plt.axis('off')

axarr[3].text(-0.03, 0, "Key\nPasses", rotation=90, ha='center',va='center', color="white", **csfont, fontsize=20, fontweight="bold")
axarr[3].text(0.415, -0.12, 'Willian', color='firebrick', fontsize=15,fontweight='bold',**csfont)
axarr[3].text(0.46, 0.22, 'Insigne', color='#12A0D7', fontsize=15,fontweight='bold',**csfont)
axarr[3].text(0.28, 0.32, 'Perišić', color='seagreen', fontsize=15,fontweight='bold',**csfont)
axarr[3].text(0.2, -0.3, 'Lamela', color='white', fontsize=15,fontweight='bold',**csfont)

axarr[4].patch.set_facecolor('#1a1d2c')

plt.sca(axarr[4])
sns.swarmplot(x=master_df["SCAPassLive"],color='white',zorder=1,alpha=0.5, size=6)
sns.swarmplot(x=willian["SCAPassLive"],color='firebrick',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=insigne["SCAPassLive"],color='#12A0D7',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=perisic["SCAPassLive"],color='seagreen',edgecolor='white',linewidth=1,zorder=1, size=13)
sns.swarmplot(x=lamela["SCAPassLive"],color='white',edgecolor='#132257',linewidth=1,zorder=1, size=13)
plt.axis('off')
axarr[4].text(0.005, 0, "Shot Creating\nActions", rotation=90, ha='center',va='center', color="white", **csfont, fontsize=20, fontweight="bold")
axarr[4].text(0.565, -0.11, 'Willian', color='firebrick', fontsize=15,fontweight='bold',**csfont)
axarr[4].text(0.58, 0.19, 'Insigne', color='#12A0D7', fontsize=15,fontweight='bold',**csfont)
axarr[4].text(0.34, 0.42, 'Perišić', color='seagreen', fontsize=15,fontweight='bold',**csfont)
axarr[4].text(0.327, -0.35, 'Lamela', color='white', fontsize=15,fontweight='bold',**csfont)


plt.rcParams['savefig.facecolor']='#1a1d2c'
plt.savefig("beeswarm", dip=500, bbox_inches='tight');
