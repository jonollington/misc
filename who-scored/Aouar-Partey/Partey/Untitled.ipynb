# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.patches as patches
warnings.filterwarnings("ignore")
from mplsoccer.pitch import Pitch
plt.style.use('ggplot')
from PIL import Image
from highlight_text import htext
from matplotlib import cm
import matplotlib.patheffects as path_effects

# %%
with open(r"Leverkusen_Atletico.json") as f:
    md = json.load(f)

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
df = json_normalize(md["events"], sep="_")

# %%
df.isGoal.value_counts()
# Out:
# True    3
# Name: isGoal, dtype: int64

# %%
df.isGoal.value_counts()
# Out:
# True    3
# Name: isGoal, dtype: int64

# %%
df['Assist'] = df['isGoal'].shift(-1)

# %%
mask1 = df['Assist'] == True
df.loc[mask1]
# Out:
#       eventId  expandedMinute          id  isTouch  minute  \
# 800       522              40  2163470437     True      40
# 1068      496              56  2163476629    False      54
# 1699      876              95  2163486651     True      93
#
#                                              qualifiers  \
# 800   [{'type': {'displayName': 'Chipped', 'value': ...
# 1068  [{'type': {'displayName': 'LeadingToGoal', 'va...
# 1699  [{'type': {'displayName': 'Length', 'value': 2...
#
#                                    satisfiedEventsTypes  second  teamId     x  \
# 800                [90, 119, 28, 123, 34, 36, 216, 217]    40.0      36  98.7
# 1068                                               [97]    10.0      63  11.1
# 1699  [90, 91, 99, 118, 116, 29, 122, 128, 202, 204,...    13.0      63  73.4
#
#          y outcomeType_displayName  outcomeType_value period_displayName  \
# 800   38.9            Unsuccessful                  0          FirstHalf
# ...

# %%
mask = (df['playerId'] == 238940) & (df['Assist'] == True)
aouar = df.loc[mask]
aouar
# Out:
#       eventId  expandedMinute          id  isTouch  minute  \
# 1699      876              95  2163486651     True      93
#
#                                              qualifiers  \
# 1699  [{'type': {'displayName': 'Length', 'value': 2...
#
#                                    satisfiedEventsTypes  second  teamId     x  \
# 1699  [90, 91, 99, 118, 116, 29, 122, 128, 202, 204,...    13.0      63  73.4
#
#          y outcomeType_displayName  outcomeType_value period_displayName  \
# 1699  57.5              Successful                  1         SecondHalf
#
#       period_value type_displayName  type_value  endX  endY  playerId  \
# 1699             2             Pass           1  86.9  61.4  238940.0
#
#       goalMouthY  goalMouthZ isShot  relatedEventId  relatedPlayerId  \
# 1699         NaN         NaN    NaN             NaN              NaN
#
#       blockedX  blockedY isGoal isOwnGoal cardType_displayName  \
# 1699       NaN       NaN    NaN       NaN                  NaN
#
# ...

# %%
aouar.to_csv('Leverkusen_Atletico.csv', index=False)

# %%
import os
import glob
import pandas as pd
import seaborn as sns

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "aouar_all1.csv", index=False, encoding='utf-8-sig')

# %%
pwd
# Out:
# '/Users/ollinj01/Football Analytics/who-scored/Aouar-Partey/Partey'
