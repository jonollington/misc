# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import json
from webdriver_manager.chrome import ChromeDriverManager
from pandas.io.json import json_normalize
import pandas as pd

# %%
# driver = webdriver.Chrome(ChromeDriverManager().install())

# driver.get('https://www.whoscored.com/Matches/1281527/Live/France-Ligue-1-2018-2019-Lille-Nimes')
# data = driver.execute_script("return matchCentreData;")

# with open('data.json', 'w', encoding='utf-8') as f:
#     json.dump(data, f, ensure_ascii=False, indent=4)
       
# driver.close()

# %%
# home_team, away_team = data["home"]["name"], data["away"]["name"]
# with open(f"{home_team}_{away_team}.json", "w") as f: ## save as Arsenal_Liverpool.json in present directory
#     json.dump(data, f, indent=4)

# %%
# data['events']

# %%
# df = json_normalize(data["events"], sep="_")

# %%
# df.isGoal.value_counts()

# %%
# df['Assist'] = df['isGoal'].shift(-1)

# %%
# mask1 = df['Assist'] == True
# df.loc[mask1]

# %%
# mask = (df['playerId'] == 239872) & (df['Assist'] == True)
# pepe = df.loc[mask]
# pepe

# %%
with open('Lille_PSG.json') as json_file:
    data = json.load(json_file)

event = []
minute = []
second = []
player = []
team = []
outcome = []
x = []
y = []
endX = []
endY = []
passtype = []


for each in data['events']:
    event.append(each['type']['displayName'])
    try:
        minute.append(each['minute'])
    except:
        minute.append('')
    try:
        second.append(each['second'])
    except:
        second.append('')
    try:
        player.append(each['playerId'])
    except:
        player.append('')
    try:
        team.append(each['teamId'])
    except:
        team.append('')
    try:
        endX.append(each['endX'])
        endY.append(each['endY'])
    except:
        endX.append('')
        endY.append('')
    outcome.append(each['outcomeType']['displayName'])
    x.append(each['x'])
    y.append(each['y'])

    for key, value in each.items():
        passType = 'OpenPlay'
        if key == 'qualifiers':
            for item in value:
                if item['type']['displayName'] == 'BigChanceCreated':
                    passType = item['type']['displayName']
                if item['type']['displayName'] == 'ShotAssist':
                    passType = item['type']['displayName']
                elif item['type']['displayName'] == 'CornerTaken':
                    passType = item['type']['displayName']
                elif item['type']['displayName'] == 'ThrowIn':
                    passType = item['type']['displayName']
            passtype.append(passType)
                
events = pd.DataFrame({'Event':event, 'Minute':minute, 'Second':second, 'Player':player, 'Team':team,
                       'Outcome':outcome, 'X':x, 'Y':y,'endX':endX, 'endY':endY, 'passtype':passtype})

# %%
data['events']
# Out:
# [{'eventId': 2,
#   'expandedMinute': 0,
#   'id': 1660434184,
#   'isTouch': False,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'second': 0,
#   'teamId': 304,
#   'type': {'displayName': 'Start', 'value': 32},
#   'x': 0,
#   'y': 0},
#  {'eventId': 2,
#   'expandedMinute': 0,
#   'id': 1408361243,
#   'isTouch': False,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'qualifiers': [],
#   'satisfiedEventsTypes': [],
#   'second': 0,
#   'teamId': 607,
#   'type': {'displayName': 'Start', 'value': 32},
#   'x': 0,
#   'y': 0},
#  {'endX': 43.5,
#   'endY': 52.7,
#   'eventId': 3,
#   'expandedMinute': 0,
#   'id': 1852676031,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 300713,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '43.5'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '52.7'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '2.9'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '7.1'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 1,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 50,
#   'y': 50},
#  {'endX': 44.6,
#   'endY': 7.5,
#   'eventId': 4,
#   'expandedMinute': 0,
#   'id': 1981760479,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 91961,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '4.7'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '44.6'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '7.5'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '31.1'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 37, 215, 217],
#   'second': 3,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 45.7,
#   'y': 53.2},
#  {'endX': 37.1,
#   'endY': 18.3,
#   'eventId': 5,
#   'expandedMinute': 0,
#   'id': 1528044914,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 104376,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '10.8'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '18.3'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '37.1'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '2.2'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 7,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 43.3,
#   'y': 5.6},
#  {'endX': 32.1,
#   'endY': 49.9,
#   'eventId': 6,
#   'expandedMinute': 0,
#   'id': 1844783709,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 361283,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '32.1'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.8'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '20.3'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '49.9'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 214, 217],
#   'second': 9,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 36.6,
#   'y': 20.9},
#  {'endX': 42.3,
#   'endY': 75,
#   'eventId': 7,
#   'expandedMinute': 0,
#   'id': 1173727826,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '42.3'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '75.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '16.3'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.3'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 36, 215, 217],
#   'second': 16,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 37.7,
#   'y': 52.1},
#  {'endX': 38.8,
#   'endY': 58.2,
#   'eventId': 8,
#   'expandedMinute': 0,
#   'id': 2076340628,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '4.4'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '38.8'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '11.9'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '58.2'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 37, 215, 217],
#   'second': 22,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 42,
#   'y': 75},
#  {'endX': 44.6,
#   'endY': 19.5,
#   'eventId': 9,
#   'expandedMinute': 0,
#   'id': 1902178472,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '4.7'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '21.2'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '19.5'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '44.6'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 37, 215, 217],
#   'second': 26,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 44.1,
#   'y': 50.6},
#  {'endX': 56.6,
#   'endY': 4.1,
#   'eventId': 10,
#   'expandedMinute': 0,
#   'id': 1594374972,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 361283,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '5.6'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '16.4'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '4.1'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '56.6'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 37, 215, 217],
#   'second': 28,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 44.6,
#   'y': 19.5},
#  {'endX': 39.4,
#   'endY': 8,
#   'eventId': 11,
#   'expandedMinute': 0,
#   'id': 1285877254,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 104376,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '39.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '2.9'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '8.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '15.1'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 31,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 53.4,
#   'y': 3.2},
#  {'endX': 33.4,
#   'endY': 36.7,
#   'eventId': 12,
#   'expandedMinute': 0,
#   'id': 1160413306,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 361283,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '36.7'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '33.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.6'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '9.9'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 35,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 34,
#   'y': 22.1},
#  {'endX': 72.7,
#   'endY': 97.2,
#   'eventId': 13,
#   'expandedMinute': 0,
#   'id': 2033175079,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '72.7'},
#    {'type': {'displayName': 'Longball', 'value': 1}},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '0.8'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Left'},
#    {'type': {'displayName': 'Chipped', 'value': 155}},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '53.6'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '97.2'}],
#   'satisfiedEventsTypes': [90, 118, 116, 123, 126, 204, 35, 36, 216, 217],
#   'second': 39,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 37.1,
#   'y': 40.7},
#  {'endX': 76.9,
#   'endY': 88.6,
#   'eventId': 14,
#   'expandedMinute': 0,
#   'id': 2098877922,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 106894,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '5.5'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Left'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '76.9'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '88.6'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.6'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 34, 37, 216, 217],
#   'second': 43,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 77.4,
#   'y': 96.6},
#  {'endX': 73.7,
#   'endY': 97.1,
#   'eventId': 15,
#   'expandedMinute': 0,
#   'id': 1829957950,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 96449,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Left'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '73.7'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '97.1'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.6'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '3.7'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 36, 216, 217],
#   'second': 44,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 73.7,
#   'y': 91.7},
#  {'endX': 68.8,
#   'endY': 82,
#   'eventId': 16,
#   'expandedMinute': 0,
#   'id': 1082530295,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 106894,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '68.8'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '82.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '11.5'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.2'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Left'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 34, 37, 216, 217],
#   'second': 45,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 73.7,
#   'y': 97.1},
#  {'endX': 70.6,
#   'endY': 75,
#   'eventId': 17,
#   'expandedMinute': 0,
#   'id': 1320875210,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 91961,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '5.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '75.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '4.7'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '70.6'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 35, 37, 216, 217],
#   'second': 47,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 67.9,
#   'y': 80.6},
#  {'endX': 67.3,
#   'endY': 75.9,
#   'eventId': 18,
#   'expandedMinute': 0,
#   'id': 1782597234,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 300713,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '67.3'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '3.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '3.5'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '75.9'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 34, 36, 216, 217],
#   'second': 48,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 70.6,
#   'y': 75},
#  {'endX': 58.7,
#   'endY': 73.2,
#   'eventId': 19,
#   'expandedMinute': 0,
#   'id': 1888510127,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 91961,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '58.7'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '73.2'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '10.3'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '3.3'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 34, 37, 215, 217],
#   'second': 49,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 68.4,
#   'y': 75.6},
#  {'endX': 45.4,
#   'endY': 32,
#   'eventId': 20,
#   'expandedMinute': 0,
#   'id': 1946853693,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 93700,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '32.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '21.5'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '45.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.4'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 37, 215, 217],
#   'second': 55,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 52,
#   'y': 62},
#  {'endX': 52.2,
#   'endY': 40.4,
#   'eventId': 21,
#   'expandedMinute': 0,
#   'id': 2042954943,
#   'isTouch': True,
#   'minute': 0,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 361283,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '12.0'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '52.2'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '40.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '0.8'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 36, 215, 217],
#   'second': 58,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 43.9,
#   'y': 28.2},
#  {'expandedMinute': 1,
#   'id': 1785258777.1,
#   'isTouch': False,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 300713,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [60],
#   'teamId': 304,
#   'type': {'displayName': 'OffsideGiven', 'value': 10000},
#   'x': 97.2,
#   'y': 49.9},
#  {'endX': 39.8,
#   'endY': 52.2,
#   'eventId': 22,
#   'expandedMinute': 1,
#   'id': 2114033796,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 93700,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '39.8'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '2.5'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '52.2'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '14.3'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 0,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 50.6,
#   'y': 39.5},
#  {'endX': 45,
#   'endY': 74.7,
#   'eventId': 23,
#   'expandedMinute': 1,
#   'id': 1785525515,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '1.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '45.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '14.6'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '74.7'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 36, 215, 217],
#   'second': 4,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 42.4,
#   'y': 53.6},
#  {'endX': 21.1,
#   'endY': 72,
#   'eventId': 24,
#   'expandedMinute': 1,
#   'id': 2008373085,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '72.0'},
#    {'type': {'displayName': 'Longball', 'value': 1}},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '3.5'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '21.1'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '38.5'}],
#   'satisfiedEventsTypes': [90, 116, 126, 34, 37, 214, 217],
#   'second': 9,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 54.9,
#   'y': 94.1},
#  {'endX': 29.4,
#   'endY': 61.5,
#   'eventId': 25,
#   'expandedMinute': 1,
#   'id': 2130842806,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 92516,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '29.4'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '9.7'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.6'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '61.5'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 37, 214, 217],
#   'second': 13,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 22.1,
#   'y': 70.2},
#  {'endX': 38.9,
#   'endY': 57.9,
#   'eventId': 26,
#   'expandedMinute': 1,
#   'id': 1813158732,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '8.2'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '57.9'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '38.9'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '6.3'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 37, 215, 217],
#   'second': 17,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 31.1,
#   'y': 58.2},
#  {'endX': 40.9,
#   'endY': 81.5,
#   'eventId': 27,
#   'expandedMinute': 1,
#   'id': 2120995634,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 91961,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '16.2'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.4'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '81.5'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '40.9'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 36, 215, 217],
#   'second': 18,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 38.9,
#   'y': 57.9},
#  {'endX': 55.2,
#   'endY': 96.3,
#   'eventId': 28,
#   'expandedMinute': 1,
#   'id': 1557320385,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '55.2'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '96.3'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Left'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '11.2'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '0.6'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 36, 215, 217],
#   'second': 21,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 46.4,
#   'y': 86.9},
#  {'endX': 47.5,
#   'endY': 91.4,
#   'eventId': 29,
#   'expandedMinute': 1,
#   'id': 1196275929,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 106894,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '11.0'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '91.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '3.5'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '47.5'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 37, 215, 217],
#   'second': 23,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 57.1,
#   'y': 97.7},
#  {'endX': 38.4,
#   'endY': 64.3,
#   'eventId': 30,
#   'expandedMinute': 1,
#   'id': 1614917733,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '38.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.2'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '19.3'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '64.3'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 37, 215, 217],
#   'second': 24,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 46.6,
#   'y': 89.7},
#  {'endX': 46.8,
#   'endY': 22.4,
#   'eventId': 31,
#   'expandedMinute': 1,
#   'id': 1444718948,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '22.4'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '22.4'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '46.8'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.0'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 37, 215, 217],
#   'second': 29,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 40.7,
#   'y': 54},
#  {'endX': 40.6,
#   'endY': 47.6,
#   'eventId': 32,
#   'expandedMinute': 1,
#   'id': 1870507117,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 361283,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '1.9'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '16.3'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '47.6'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '40.6'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 32,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 45.7,
#   'y': 24.9},
#  {'endX': 53.6,
#   'endY': 48.7,
#   'eventId': 33,
#   'expandedMinute': 1,
#   'id': 1221083930,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '53.6'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '9.7'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '48.7'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '6.3'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 37, 215, 217],
#   'second': 35,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 44.4,
#   'y': 49.1},
#  {'endX': 48.4,
#   'endY': 70.7,
#   'eventId': 34,
#   'expandedMinute': 1,
#   'id': 1789131997,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 96449,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '15.9'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '48.4'},
#    {'type': {'displayName': 'LayOff', 'value': 156}},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.9'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '70.7'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 36,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 53.6,
#   'y': 48.7},
#  {'eventId': 35,
#   'expandedMinute': 1,
#   'id': 1385150488,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [90],
#   'second': 39,
#   'teamId': 304,
#   'type': {'displayName': 'BallTouch', 'value': 61},
#   'x': 46.6,
#   'y': 73.6},
#  {'eventId': 36,
#   'expandedMinute': 1,
#   'id': 1835347498,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 91961,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Center'}],
#   'satisfiedEventsTypes': [90],
#   'second': 40,
#   'teamId': 304,
#   'type': {'displayName': 'BallTouch', 'value': 61},
#   'x': 56.6,
#   'y': 72.4},
#  {'endX': 80.2,
#   'endY': 6.4,
#   'eventId': 37,
#   'expandedMinute': 1,
#   'id': 1167002302,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Right'},
#    {'type': {'displayName': 'Chipped', 'value': 155}},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.3'},
#    {'type': {'displayName': 'Longball', 'value': 1}},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '80.2'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '6.4'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '49.4'}],
#   'satisfiedEventsTypes': [90, 118, 116, 123, 126, 204, 35, 37, 216, 217],
#   'second': 41,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 54.6,
#   'y': 67.4},
#  {'endX': 86.3,
#   'endY': 24.4,
#   'eventId': 38,
#   'expandedMinute': 1,
#   'id': 1615949272,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 104376,
#   'qualifiers': [{'type': {'displayName': 'HeadPass', 'value': 3}},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '13.9'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '86.3'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '24.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.1'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 138, 204, 35, 36, 216, 217],
#   'second': 45,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 80.2,
#   'y': 6.2},
#  {'endX': 86.9,
#   'endY': 28.5,
#   'eventId': 39,
#   'expandedMinute': 1,
#   'id': 1517622961,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 5780,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Center'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '3.5'},
#    {'type': {'displayName': 'ShotAssist', 'value': 210}},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.9'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '86.9'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '28.5'},
#    {'type': {'displayName': 'KeyPass', 'value': 11113}}],
#   'satisfiedEventsTypes': [90,
#    118,
#    116,
#    29,
#    122,
#    204,
#    39,
#    45,
#    34,
#    36,
#    216,
#    217],
#   'second': 46,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 88,
#   'y': 23.6},
#  {'blockedX': 95.6,
#   'blockedY': 48.7,
#   'eventId': 40,
#   'expandedMinute': 1,
#   'goalMouthY': 60.7,
#   'goalMouthZ': 1.4,
#   'id': 1349862611,
#   'isShot': True,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 104376,
#   'qualifiers': [{'type': {'displayName': 'BoxRight', 'value': 63}},
#    {'type': {'displayName': 'RegularPlay', 'value': 22}},
#    {'type': {'displayName': 'MissLeft', 'value': 73}},
#    {'type': {'displayName': 'RelatedEventId', 'value': 55}, 'value': '39'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'RightFoot', 'value': 20}},
#    {'type': {'displayName': 'GoalMouthZ', 'value': 103}, 'value': '1.4'},
#    {'type': {'displayName': 'GoalMouthY', 'value': 102}, 'value': '60.7'},
#    {'type': {'displayName': 'BlockedX', 'value': 146}, 'value': '95.6'},
#    {'type': {'displayName': 'BlockedY', 'value': 147}, 'value': '48.7'},
#    {'type': {'displayName': 'Assisted', 'value': 29}}],
#   'relatedEventId': 39,
#   'relatedPlayerId': 5780,
#   'satisfiedEventsTypes': [90, 6, 89, 9, 1, 3, 11],
#   'second': 49,
#   'teamId': 304,
#   'type': {'displayName': 'MissedShots', 'value': 13},
#   'x': 89.5,
#   'y': 33.1},
#  {'eventId': 4,
#   'expandedMinute': 1,
#   'id': 1393588369,
#   'isTouch': False,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 136481,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [61],
#   'second': 53,
#   'teamId': 607,
#   'type': {'displayName': 'OffsideProvoked', 'value': 55},
#   'x': 4.8,
#   'y': 49},
#  {'endX': 97.2,
#   'endY': 49.9,
#   'eventId': 41,
#   'expandedMinute': 1,
#   'id': 1785258777,
#   'isTouch': True,
#   'minute': 1,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 104376,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Center'},
#    {'type': {'displayName': 'PlayerCaughtOffside', 'value': 7},
#     'value': '300713'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '49.9'},
#    {'type': {'displayName': 'GoalDisallowed', 'value': 8}},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '97.2'}],
#   'satisfiedEventsTypes': [90, 216],
#   'second': 53,
#   'teamId': 304,
#   'type': {'displayName': 'OffsidePass', 'value': 2},
#   'x': 93.6,
#   'y': 34.9},
#  {'endX': 42.9,
#   'endY': 50.1,
#   'eventId': 5,
#   'expandedMinute': 2,
#   'id': 1733027949,
#   'isTouch': True,
#   'minute': 2,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 141646,
#   'qualifiers': [{'type': {'displayName': 'IndirectFreekickTaken',
#      'value': 241}},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '0.1'},
#    {'type': {'displayName': 'Longball', 'value': 1}},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '37.2'},
#    {'type': {'displayName': 'FreekickTaken', 'value': 5}},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '50.1'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '42.9'}],
#   'satisfiedEventsTypes': [90, 116, 126, 131, 35, 36, 215, 217],
#   'second': 45,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 7.6,
#   'y': 45.1},
#  {'endX': 38,
#   'endY': 66.3,
#   'eventId': 6,
#   'expandedMinute': 2,
#   'id': 1474670538,
#   'isTouch': True,
#   'minute': 2,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 329409,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '66.3'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '38.0'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '2.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '12.2'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 36, 215, 217],
#   'second': 46,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 42.9,
#   'y': 50.1},
#  {'endX': 35.8,
#   'endY': 33.4,
#   'eventId': 7,
#   'expandedMinute': 2,
#   'id': 1964284076,
#   'isTouch': True,
#   'minute': 2,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 143193,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '35.8'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '33.4'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '19.1'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 116, 29, 34, 37, 215, 217],
#   'second': 49,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 41.3,
#   'y': 60.2},
#  {'endX': 74.6,
#   'endY': 10.2,
#   'eventId': 8,
#   'expandedMinute': 2,
#   'id': 2087718637,
#   'isTouch': True,
#   'minute': 2,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 19859,
#   'qualifiers': [{'type': {'displayName': 'Longball', 'value': 1}},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '10.2'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'},
#    {'type': {'displayName': 'Chipped', 'value': 155}},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '35.9'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '6.1'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '74.6'}],
#   'satisfiedEventsTypes': [90, 119, 123, 127, 35, 37, 216, 217],
#   'second': 52,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 41,
#   'y': 20},
#  {'eventId': 42,
#   'expandedMinute': 2,
#   'id': 1996252212,
#   'isTouch': True,
#   'minute': 2,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 100, 55],
#   'second': 54,
#   'teamId': 304,
#   'type': {'displayName': 'Interception', 'value': 8},
#   'x': 23.9,
#   'y': 90.5},
#  {'endX': 54.6,
#   'endY': 4.6,
#   'eventId': 10,
#   'expandedMinute': 3,
#   'id': 1406567255,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 136481,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '54.6'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '2.9'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '4.6'},
#    {'type': {'displayName': 'ThrowIn', 'value': 107}},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '17.7'}],
#   'satisfiedEventsTypes': [90, 211, 34, 36, 215],
#   'second': 1,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 70.9,
#   'y': 0},
#  {'endX': 56.1,
#   'endY': 24.3,
#   'eventId': 11,
#   'expandedMinute': 3,
#   'id': 1547380140,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 19859,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '56.1'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '12.6'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.5'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '24.3'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 36, 215, 217],
#   'second': 3,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 55.6,
#   'y': 5.8},
#  {'endX': 51.9,
#   'endY': 77.6,
#   'eventId': 12,
#   'expandedMinute': 3,
#   'id': 1274754875,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 117776,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '77.6'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.7'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '33.2'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '51.9'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'Longball', 'value': 1}}],
#   'satisfiedEventsTypes': [90, 118, 116, 126, 34, 36, 215, 217],
#   'second': 6,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 56.4,
#   'y': 29.2},
#  {'endX': 62.1,
#   'endY': 78.3,
#   'eventId': 13,
#   'expandedMinute': 3,
#   'id': 1777529106,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 143193,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '10.5'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '6.3'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '78.3'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '62.1'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 37, 215, 217],
#   'second': 10,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 52.1,
#   'y': 78.5},
#  {'endX': 55.1,
#   'endY': 74.4,
#   'eventId': 14,
#   'expandedMinute': 3,
#   'id': 2046497376,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 329409,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '74.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '55.1'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.8'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '10.1'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 37, 215, 217],
#   'second': 13,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 54.4,
#   'y': 89.2},
#  {'eventId': 15,
#   'expandedMinute': 3,
#   'id': 1603437618,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 117776,
#   'qualifiers': [{'type': {'displayName': 'Foul', 'value': 13}},
#    {'type': {'displayName': 'OppositeRelatedEvent', 'value': 233},
#     'value': '44'},
#    {'type': {'displayName': 'Offensive', 'value': 286}},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Left'}],
#   'satisfiedEventsTypes': [90, 62],
#   'second': 15,
#   'teamId': 607,
#   'type': {'displayName': 'Foul', 'value': 4},
#   'x': 54.8,
#   'y': 77.8},
#  {'eventId': 44,
#   'expandedMinute': 3,
#   'id': 1381694628,
#   'isTouch': False,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 96449,
#   'qualifiers': [{'type': {'displayName': 'Defensive', 'value': 285}},
#    {'type': {'displayName': 'Foul', 'value': 13}},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'OppositeRelatedEvent', 'value': 233},
#     'value': '15'}],
#   'satisfiedEventsTypes': [63],
#   'second': 15,
#   'teamId': 304,
#   'type': {'displayName': 'Foul', 'value': 4},
#   'x': 45.2,
#   'y': 22.2},
#  {'endX': 52.7,
#   'endY': 58.5,
#   'eventId': 16,
#   'expandedMinute': 3,
#   'id': 1073995328,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 329409,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '52.7'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'FreekickTaken', 'value': 5}},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '7.3'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '58.5'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 131, 35, 37, 215, 217],
#   'second': 29,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 50.6,
#   'y': 68.8},
#  {'endX': 50.8,
#   'endY': 26.7,
#   'eventId': 17,
#   'expandedMinute': 3,
#   'id': 1193696039,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 117776,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '26.7'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.6'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '20.6'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '50.8'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 34, 37, 215, 217],
#   'second': 31,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 52.5,
#   'y': 56.9},
#  {'endX': 58.1,
#   'endY': 5.5,
#   'eventId': 18,
#   'expandedMinute': 3,
#   'id': 2064923213,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 19859,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '5.5'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.2'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '14.4'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '58.1'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 37, 215, 217],
#   'second': 34,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 51.3,
#   'y': 23.9},
#  {'endX': 68.1,
#   'endY': 18.4,
#   'eventId': 19,
#   'expandedMinute': 3,
#   'id': 1193118973,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 239872,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '68.1'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '18.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.0'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '8.1'}],
#   'satisfiedEventsTypes': [90, 119, 28, 35, 36, 216, 217],
#   'second': 38,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 64.2,
#   'y': 8.1},
#  {'eventId': 45,
#   'expandedMinute': 3,
#   'id': 1467793441,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'}],
#   'satisfiedEventsTypes': [90],
#   'second': 39,
#   'teamId': 304,
#   'type': {'displayName': 'BallTouch', 'value': 61},
#   'x': 25.9,
#   'y': 83.5},
#  {'eventId': 46,
#   'expandedMinute': 3,
#   'id': 1284839542,
#   'isTouch': False,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [92],
#   'second': 40,
#   'teamId': 304,
#   'type': {'displayName': 'BallRecovery', 'value': 49},
#   'x': 21.3,
#   'y': 70.5},
#  {'endX': 45.8,
#   'endY': 71.7,
#   'eventId': 47,
#   'expandedMinute': 3,
#   'id': 1712274594,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 28550,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '71.7'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '25.7'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '45.8'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '0.0'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 36, 215, 217],
#   'second': 41,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 21.3,
#   'y': 70.5},
#  {'endX': 44.8,
#   'endY': 89.9,
#   'eventId': 48,
#   'expandedMinute': 3,
#   'id': 1500299896,
#   'isTouch': True,
#   'minute': 3,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'FirstHalf', 'value': 1},
#   'playerId': 300713,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '44.8'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '12.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.7'},
# ...
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 5780,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Right'}],
#   'satisfiedEventsTypes': [90],
#   'second': 47,
#   'teamId': 304,
#   'type': {'displayName': 'BallTouch', 'value': 61},
#   'x': 84.9,
#   'y': 8.1},
#  {'eventId': 472,
#   'expandedMinute': 66,
#   'id': 1879737369,
#   'isTouch': True,
#   'minute': 58,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 322094,
#   'qualifiers': [{'type': {'displayName': 'Defensive', 'value': 285}},
#    {'type': {'displayName': 'OppositeRelatedEvent', 'value': 233},
#     'value': '613'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 52],
#   'second': 51,
#   'teamId': 607,
#   'type': {'displayName': 'TakeOn', 'value': 3},
#   'x': 30,
#   'y': 95.7},
#  {'eventId': 613,
#   'expandedMinute': 66,
#   'id': 1089503108,
#   'isTouch': True,
#   'minute': 58,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 255167,
#   'qualifiers': [{'type': {'displayName': 'OppositeRelatedEvent',
#      'value': 233},
#     'value': '472'},
#    {'type': {'displayName': 'Offensive', 'value': 286}},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'}],
#   'satisfiedEventsTypes': [90, 142],
#   'second': 51,
#   'teamId': 304,
#   'type': {'displayName': 'Tackle', 'value': 7},
#   'x': 70,
#   'y': 4.3},
#  {'eventId': 614,
#   'expandedMinute': 66,
#   'id': 1595288039,
#   'isTouch': False,
#   'minute': 58,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 5780,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [92],
#   'second': 52,
#   'teamId': 304,
#   'type': {'displayName': 'BallRecovery', 'value': 49},
#   'x': 71.1,
#   'y': 4.7},
#  {'endX': 60.5,
#   'endY': 19,
#   'eventId': 615,
#   'expandedMinute': 66,
#   'id': 1244756953,
#   'isTouch': True,
#   'minute': 58,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 5780,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '60.5'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '19.0'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '2.2'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '10.6'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 34, 36, 215, 217],
#   'second': 53,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 66.4,
#   'y': 6.4},
#  {'endX': 71.4,
#   'endY': 5.8,
#   'eventId': 616,
#   'expandedMinute': 67,
#   'id': 1615022681,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 93700,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '71.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Right'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.2'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '14.5'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '5.8'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 35, 37, 216, 217],
#   'second': 0,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 64.6,
#   'y': 24.3},
#  {'endX': 72,
#   'endY': 45.4,
#   'eventId': 617,
#   'expandedMinute': 67,
#   'id': 1968139114,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 5780,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '72.0'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '45.4'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.8'},
#    {'type': {'displayName': 'Chipped', 'value': 155}},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '27.5'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'}],
#   'satisfiedEventsTypes': [90, 119, 28, 123, 34, 36, 216, 217],
#   'second': 4,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 77.6,
#   'y': 5.9},
#  {'endX': 27,
#   'endY': 62,
#   'eventId': 473,
#   'expandedMinute': 67,
#   'id': 1340242460,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 239872,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Back'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '27.0'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.9'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '7.6'},
#    {'type': {'displayName': 'HeadPass', 'value': 3}},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '62.0'}],
#   'satisfiedEventsTypes': [90, 116, 29, 138, 34, 36, 214, 217],
#   'second': 7,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 29.4,
#   'y': 51.5},
#  {'eventId': 474,
#   'expandedMinute': 67,
#   'id': 1750943966,
#   'isTouch': False,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 117776,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [92],
#   'second': 8,
#   'teamId': 607,
#   'type': {'displayName': 'BallRecovery', 'value': 49},
#   'x': 28.3,
#   'y': 61.8},
#  {'endX': 47.1,
#   'endY': 41.8,
#   'eventId': 475,
#   'expandedMinute': 67,
#   'id': 1470798595,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 117776,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '41.8'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '47.1'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.8'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '19.1'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 37, 215, 217],
#   'second': 10,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 30.9,
#   'y': 54.6},
#  {'endX': 55.1,
#   'endY': 54.6,
#   'eventId': 476,
#   'expandedMinute': 67,
#   'id': 1648472348,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 239872,
#   'qualifiers': [{'type': {'displayName': 'Angle', 'value': 213},
#     'value': '0.8'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '55.1'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '12.1'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '54.6'}],
#   'satisfiedEventsTypes': [90, 119, 28, 35, 36, 215, 217],
#   'second': 12,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 47.1,
#   'y': 41.8},
#  {'eventId': 618,
#   'expandedMinute': 67,
#   'id': 1442627036,
#   'isTouch': False,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 247800,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [92],
#   'second': 13,
#   'teamId': 304,
#   'type': {'displayName': 'BallRecovery', 'value': 49},
#   'x': 48.3,
#   'y': 46.1},
#  {'endX': 55,
#   'endY': 37.3,
#   'eventId': 619,
#   'expandedMinute': 67,
#   'id': 2020154399,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 247800,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '37.3'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '55.0'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '9.2'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.6'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 37, 215, 217],
#   'second': 14,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 48.3,
#   'y': 46.1},
#  {'endX': 59.6,
#   'endY': 26.2,
#   'eventId': 620,
#   'expandedMinute': 67,
#   'id': 1201296588,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 93700,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Center'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.4'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '26.2'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '12.9'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '59.6'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 35, 37, 215, 217],
#   'second': 17,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 51.4,
#   'y': 40.3},
#  {'endX': 67.5,
#   'endY': 76.4,
#   'eventId': 621,
#   'expandedMinute': 67,
#   'id': 1279573298,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 5780,
#   'qualifiers': [{'type': {'displayName': 'Chipped', 'value': 155}},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '67.5'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '36.2'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '76.4'},
#    {'type': {'displayName': 'Longball', 'value': 1}},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '1.4'}],
#   'satisfiedEventsTypes': [90, 118, 116, 123, 126, 204, 35, 36, 216, 217],
#   'second': 20,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 61.4,
#   'y': 24},
#  {'endX': 75.7,
#   'endY': 60.5,
#   'eventId': 622,
#   'expandedMinute': 67,
#   'id': 1331745424,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 96449,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Center'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '60.5'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '4.7'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '75.7'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '8.7'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 34, 37, 216, 217],
#   'second': 25,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 75.9,
#   'y': 73.3},
#  {'endX': 88.4,
#   'endY': 64.2,
#   'eventId': 623,
#   'expandedMinute': 67,
#   'id': 1363375610,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 300713,
#   'qualifiers': [{'type': {'displayName': 'PassEndY', 'value': 141},
#     'value': '64.2'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Center'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '0.2'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '88.4'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '13.6'}],
#   'satisfiedEventsTypes': [90, 118, 116, 29, 204, 35, 36, 216, 217],
#   'second': 26,
#   'teamId': 304,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 75.7,
#   'y': 60.5},
#  {'eventId': 624,
#   'expandedMinute': 67,
#   'id': 1454231863,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Unsuccessful', 'value': 0},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 96449,
#   'qualifiers': [{'type': {'displayName': 'Zone', 'value': 56},
#     'value': 'Center'}],
#   'satisfiedEventsTypes': [90, 68],
#   'second': 28,
#   'teamId': 304,
#   'type': {'displayName': 'BallTouch', 'value': 61},
#   'x': 88.6,
#   'y': 64.2},
#  {'eventId': 477,
#   'expandedMinute': 67,
#   'id': 1160454221,
#   'isTouch': False,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 141646,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [92],
#   'second': 31,
#   'teamId': 607,
#   'type': {'displayName': 'KeeperPickup', 'value': 52},
#   'x': 4.5,
#   'y': 41.9},
#  {'endX': 31.8,
#   'endY': 5.9,
#   'eventId': 478,
#   'expandedMinute': 67,
#   'id': 1927206461,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 141646,
#   'qualifiers': [{'type': {'displayName': 'Length', 'value': 212},
#     'value': '31.2'},
#    {'type': {'displayName': 'PassEndX', 'value': 140}, 'value': '31.8'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.4'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '5.9'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 37, 214, 217],
#   'second': 39,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 13.6,
#   'y': 42.2},
#  {'endX': 19.6,
#   'endY': 3.7,
#   'eventId': 481,
#   'expandedMinute': 67,
#   'id': 1084584898,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 136481,
#   'qualifiers': [{'type': {'displayName': 'PassEndX', 'value': 140},
#     'value': '19.6'},
#    {'type': {'displayName': 'Angle', 'value': 213}, 'value': '5.4'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'},
#    {'type': {'displayName': 'Length', 'value': 212}, 'value': '3.1'},
#    {'type': {'displayName': 'PassEndY', 'value': 141}, 'value': '3.7'}],
#   'satisfiedEventsTypes': [90, 116, 29, 35, 37, 214, 217],
#   'second': 40,
#   'teamId': 607,
#   'type': {'displayName': 'Pass', 'value': 1},
#   'x': 17.7,
#   'y': 7.1},
#  {'eventId': 479,
#   'expandedMinute': 67,
#   'id': 1724404526,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 239872,
#   'qualifiers': [{'type': {'displayName': 'Defensive', 'value': 285}},
#    {'type': {'displayName': 'OppositeRelatedEvent', 'value': 233},
#     'value': '625'},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Back'}],
#   'satisfiedEventsTypes': [90, 69],
#   'second': 43,
#   'teamId': 607,
#   'type': {'displayName': 'Dispossessed', 'value': 50},
#   'x': 29.6,
#   'y': 8.6},
#  {'eventId': 625,
#   'expandedMinute': 67,
#   'id': 1908946699,
#   'isTouch': True,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 91961,
#   'qualifiers': [{'type': {'displayName': 'OppositeRelatedEvent',
#      'value': 233},
#     'value': '479'},
#    {'type': {'displayName': 'Offensive', 'value': 286}},
#    {'type': {'displayName': 'Zone', 'value': 56}, 'value': 'Left'}],
#   'satisfiedEventsTypes': [90, 142],
#   'second': 43,
#   'teamId': 304,
#   'type': {'displayName': 'Tackle', 'value': 7},
#   'x': 70.4,
#   'y': 91.4},
#  {'eventId': 626,
#   'expandedMinute': 67,
#   'id': 1189919587,
#   'isTouch': False,
#   'minute': 59,
#   'outcomeType': {'displayName': 'Successful', 'value': 1},
#   'period': {'displayName': 'SecondHalf', 'value': 2},
#   'playerId': 96449,
#   'qualifiers': [],
#   'satisfiedEventsTypes': [92],
#   'second': 46,
#   'teamId': 304,
#   'type': {'displayName': 'BallRecovery', 'value': 49},
#   'x': 75.2,
#   'y': 78.4},
#  ...]

# %%
events.head()
# Out:
#    Event  Minute Second  Player  Team     Outcome     X     Y  endX  endY  \
# 0  Start       0      0           607  Successful   0.0   0.0
# 1  Start       0      0           245  Successful   0.0   0.0
# 2   Pass       0      1   23054   607  Successful  50.1  50.3  36.7  50.1
# 3   Pass       0      3  117776   607  Successful  34.6  39.7  35.4   8.3
# 4   Pass       0      5  136481   607  Successful  37.0   8.5  33.2  25.8
#
#    passtype
# 0  OpenPlay
# 1  OpenPlay
# 2  OpenPlay
# 3  OpenPlay
# 4  OpenPlay

# %%
mask = (events['Player'] == 239872) & (events['passtype'] == 'BigChanceCreated')
pepe = events.loc[mask]
pepe
# Out:
# Empty DataFrame
# Columns: [Event, Minute, Second, Player, Team, Outcome, X, Y, endX, endY, passtype]
# Index: []

# %%
mask = (events['Event'] == 'Goal')
goal = events.loc[mask]
goal
# Out:
#      Event  Minute Second  Player  Team     Outcome     X     Y endX endY  \
# 930   Goal      50     20   23054   607  Successful  89.2  39.2
# 1163  Goal      63     20  241019   607  Successful  89.3  56.3
# 1235  Goal      69     13  136481   607  Successful  90.5  34.2
# 1373  Goal      79     39  239872   607  Successful  97.2  47.0
# 1542  Goal      91     56   69742   607  Successful  81.9  52.8
#
#       passtype
# 930   OpenPlay
# 1163  OpenPlay
# 1235  OpenPlay
# 1373  OpenPlay
# 1542  OpenPlay

# %%
events['Assist'] = (events['Event'] == 'Goal').shift(-1)
# events['Assist_2nd'] = (events['Event'] == 'Goal').shift(-2)

# %%
mask = (events['Player'] == 239872) & (events['Event'] == 'Goal')
pepe_goal = events.loc[mask]
pepe_goal.head()
# Out:
#      Event  Minute Second  Player  Team     Outcome     X     Y endX endY  \
# 1373  Goal      79     39  239872   607  Successful  97.2  47.0
#
#       passtype Assist
# 1373  OpenPlay  False

# %%
mask = (events['Player'] == 239872) & (events['Assist'] == True)
pepe_assist = events.loc[mask]
pepe_assist.head()
# Out:
# Empty DataFrame
# Columns: [Event, Minute, Second, Player, Team, Outcome, X, Y, endX, endY, passtype, Assist]
# Index: []

# %%
# mask = (events['Player'] == 239872) & (events['Assist_2nd'] == True)
# pepe_assist = events.loc[mask]
# pepe_assist.head()

# %%
events.to_csv('Lille_Nimes.csv', index=False)

# %%
import os
import glob
import pandas as pd

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "pepe_all.csv", index=False, encoding='utf-8-sig')
