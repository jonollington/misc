# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.patches as patches
warnings.filterwarnings("ignore")
from mplsoccer.pitch import Pitch
plt.style.use('ggplot')
from PIL import Image
from highlight_text import htext
from matplotlib import cm
import matplotlib.patheffects as path_effects

# %%
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %% [markdown]
# ________________________________________________

# %%
events = pd.read_csv('./JSON/Arsenal_19-20/pepe_arse_all.csv')

# %%
mask = (events['Player'] == 239872)
pepe = events.loc[mask]
pepe
# Out:
#                  Event  Minute  Second    Player  Team       Outcome     X  \
# 1257    SubstitutionOn      70    25.0  239872.0    13    Successful   0.0
# 1295      BallRecovery      72    23.0  239872.0    13    Successful  68.7
# 1296            TakeOn      72    27.0  239872.0    13  Unsuccessful  85.6
# 1308              Pass      73     7.0  239872.0    13  Unsuccessful  78.2
# 1389              Pass      77    12.0  239872.0    13    Successful  19.9
# ...                ...     ...     ...       ...   ...           ...   ...
# 59021    CornerAwarded      53    30.0  239872.0    13    Successful  98.8
# 59099             Pass      58    46.0  239872.0    13    Successful  49.0
# 59122     Dispossessed      60    33.0  239872.0    13    Successful  69.8
# 59133           Aerial      61    16.0  239872.0    13  Unsuccessful  88.3
# 59147  SubstitutionOff      62    22.0  239872.0    13    Successful   0.0
#
#           Y  endX  endY  passtype Assist Assist_2nd
# 1257    0.0   NaN   NaN  OpenPlay  False        NaN
# 1295   14.1   NaN   NaN  OpenPlay  False        NaN
# 1296   12.1   NaN   NaN  OpenPlay  False        NaN
# 1308   12.6  76.0   0.0  OpenPlay  False        NaN
# 1389    9.7  11.0   5.9  OpenPlay  False        NaN
# ...     ...   ...   ...       ...    ...        ...
# 59021  65.2   NaN   NaN  OpenPlay  False        NaN
# 59099   3.5  30.3   3.8  OpenPlay  False        NaN
# 59122   1.8   NaN   NaN  OpenPlay  False        NaN
# 59133  45.6   NaN   NaN  OpenPlay  False        NaN
# 59147   0.0   NaN   NaN  OpenPlay  False        NaN
#
# [1521 rows x 13 columns]

# %%
mask = (pepe['passtype'] == 'BigChanceCreated') & (pepe['Event'] == 'Pass') & (pepe['Assist_2nd'] != True)
pepe_bcc = pepe.loc[mask]
len(pepe_bcc)
# Out:
# 7

# %%
mask = (pepe['passtype'] == 'BigChanceCreated') & (pepe['Event'] != 'Pass') & (pepe['Assist_2nd'] != True)
pepe_bcc1 = pepe.loc[mask]
len(pepe_bcc1)
# Out:
# 0

# %%
mask = (pepe['Event'] == 'Goal') & (pepe['Y'] != 50) & (pepe['Event'] == 'Goal') & (pepe['Y'] != 50.7) & (pepe['Event'] == 'Goal') & (pepe['Y'] != 50.1)
pepe_goal = pepe.loc[mask]
len(pepe_goal)
# Out:
# 4

# %%
mask = (pepe['Assist'] == True) & (pepe['Event'] == 'Pass')
pepe_assist = pepe.loc[mask]
len(pepe_assist)
# Out:
# 1

# %%
mask = (pepe['Assist_2nd'] == True) & (pepe['Event'] == 'Pass') & ((pepe['X'] < 99) & (pepe['Y'] < 99))
pepe_assist2 = pepe.loc[mask]
len(pepe_assist2)
# Out:
# 1

# %%
mask3 = (pepe['Event'] == 'MissedShots') | (pepe['Event'] == 'SavedShot')
pepe_shot = pepe.loc[mask3]
len(pepe_shot)
# Out:
# 43

# %%
# mask5 = (mesut['passtype'] == 'IntentionalGoalAssist') & ((mesut['x'] > 99) & (mesut['y'] > 99)) | (mesut['passtype'] == 'IntentionalGoalAssist') & ((mesut['x'] > 99) & (mesut['y'] < 1)) & ((mesut['x'] > 99) & (mesut['y'] < 1))
# corner = mesut.loc[mask5]
# len(corner)

# %%
# mask5 = (mesut['passtype'] == 'BigChanceCreated') & ((mesut['x'] > 99) & (mesut['y'] < 1))
# corner1 = mesut.loc[mask5]
# corner1

# %%
mask5 = (pepe['passtype'] != 'IntentionalGoalAssist') & (pepe['passtype'] != 'BigChanceCreated') & (pepe['X'] < 99) & (pepe['Y'] < 99) & ((pepe['X'] > 1) & (pepe['Y'] > 1))
touch = pepe.loc[mask5]

# %%
# mesut["endX"] = pd.to_numeric(events["endX"])
# mesut["endY"] = pd.to_numeric(events["endY"])

# %%
background = "#313332"
line = '#696969'
text_color ='white'
touches = '#f62681'
assisted = "#45c7e8"
goal = '#59c08a'
title_font = "BBC Reith Sans"
body_font = "BBC Reith Sans"

pitch = Pitch(figsize=(15,15),orientation='vertical',view='half',goal_type='box',pitch_type='opta', pad_bottom=-0.008,
              pitch_color=background, line_color=line,constrained_layout=False)

fig, ax = pitch.draw()

#touches
x = touch.X.values
y = touch.Y.values
ax.scatter(y,x,color='white', s=150, zorder=12, alpha=0.03)

#assists
style="wedge,tail_width=0.4"
xA = pepe_assist.X.values
yA = pepe_assist.Y.values
xEA = pepe_assist.endX.values
yEA = pepe_assist.endY.values

plt.scatter(yEA,xEA,color=assisted, s=150, ec=background, lw=1.5,zorder=14, alpha=0.7)

for i in range(len(pepe_assist)):
    plt.annotate('', xy=(yA[i],xA[i]), xytext=(yEA[i],xEA[i]), zorder=12, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))
    
xA2 = pepe_assist2.X.values
yA2 = pepe_assist2.Y.values
xEA2 = pepe_assist2.endX.values
yEA2 = pepe_assist2.endY.values

plt.scatter(yEA2,xEA2,color=assisted, s=150, ec=background, lw=1.5,zorder=14, alpha=0.7)

for i in range(len(pepe_assist2)):
    plt.annotate('', xy=(yA2[i],xA2[i]), xytext=(yEA2[i],xEA2[i]), zorder=12, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))

    
#chances created
xC = pepe_bcc.X.values
yC = pepe_bcc.Y.values
xEC = pepe_bcc.endX.values
yEC = pepe_bcc.endY.values
plt.scatter(yEC,xEC,c=background, ec=assisted,lw=1.5, s=130, zorder=12, alpha=0.7)

for i in range(len(pepe_bcc)):
    plt.annotate('', xy=(yC[i],xC[i]), xytext=(yEC[i],xEC[i]), zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))

xC1 = pepe_bcc1.X.values
yC1 = pepe_bcc1.Y.values
plt.scatter(yC1,xC1,c=background, ec=assisted,lw=1.5, s=130, zorder=12, alpha=0.7)    

    
#shots
xS = pepe_shot.X.values
yS = pepe_shot.Y.values

plt.scatter(yS,xS,color=background, ec=goal, lw=1.5, s=130, zorder=10, alpha=0.5)

#goals
xG = pepe_goal.X.values
yG = pepe_goal.Y.values
plt.scatter(yG,xG,color=goal, ec=background, lw=1, s=150, zorder=15, alpha=0.8)

fig.text(0.035, 0.946, "Nicolas Pépé",fontsize=35, fontfamily=body_font, color=text_color, weight='bold',zorder=2)
fig.text(0.035, 0.923, "Arsenal | English Premier League | Season 2019/2020",fontsize=20, fontfamily=body_font, color=text_color,zorder=2)
fig.text(0.035, 0.96, "n",fontsize=20,color=background,zorder=1)
n = fig.text(0.925, 0.896, "Nicolas Pépé",fontsize=19, fontfamily=body_font, color=background,zorder=2, ha='center')
fig.text(0.88, 0.863, "How well did                               \ncompare in P90 goal\ncontributions?",fontsize=16, fontfamily=body_font, color=text_color,zorder=2, ha='center')

n.set_path_effects([path_effects.withStroke(linewidth=4,foreground=assisted)])

# # ax2 = fig.add_axes([0.005,0.803,0.8,0.12]) # beeswarm

# # ax2.patch.set_facecolor(background)
# # plt.sca(ax2)
# # sns.swarmplot(x=cont["G+A"],color='silver',zorder=1,alpha=1, size=6)
# # sns.swarmplot(x=ozil["G+A"],color=background,ec=assisted,linewidth=4,zorder=1, size=15)
# # plt.axis('off')

# # ax2 = fig.add_axes([0.9,0.90,0.075,0.075]) # badge
# # ax2.axis("off")
# # img = Image.open('./Arsenal.png')
# # ax2.imshow(img)

ax3 = fig.add_axes([0.03,0.11,0.05,0.02])
ax3.axis("off")
ax3.scatter([0.03],[0.05],c='white', s=200, zorder=12, alpha=0.3)
fig.text(0.065, 0.115, "all passes",fontsize=16, fontfamily=body_font, color=text_color)

ax4 = fig.add_axes([0.145,0.11,0.05,0.02])
ax4.axis("off")
ax4.scatter([0.145],[0.05],ec=goal, c=background, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.182, 0.115, "shot",fontsize=16, fontfamily=body_font, color=text_color)

ax5 = fig.add_axes([0.226,0.11,0.05,0.02])
ax5.axis("off")
ax5.scatter([0.226],[0.05],c=goal, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.263, 0.115, "goal",fontsize=16, fontfamily=body_font, color=text_color)

ax6 = fig.add_axes([0.31,0.11,0.05,0.02])
ax6.axis("off")
ax6.annotate('', [0.31,0.5],[1.5,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color=assisted, shrinkA=6, alpha=0.6))

ax7 = fig.add_axes([0.36,0.11,0.05,0.02])
ax7.axis("off")
ax7.scatter([0.36],[0.05],ec=assisted, c=background, s=200, linewidth=1.5, zorder=12, alpha=0.9)
fig.text(0.397, 0.115, "big chance created",fontsize=16, fontfamily=body_font, color=text_color)

ax8 = fig.add_axes([0.535,0.11,0.05,0.02])
ax8.axis("off")
ax8.annotate('', [0.535,0.5],[1.6,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color=assisted, shrinkA=6, alpha=0.6))

ax9 = fig.add_axes([0.588,0.11,0.06,0.02])
ax9.axis("off")
ax9.scatter([0.583],[0.05], c=assisted, s=200, linewidth=1.5, zorder=12, alpha=0.9)
fig.text(0.629, 0.115, "assist",fontsize=16, fontfamily=body_font, color=text_color)

fig.text(0.851, 0.115, "@jonollington",fontsize=17, fontfamily=body_font, color=text_color)

plt.rcParams['axes.facecolor']=background
plt.rcParams['savefig.facecolor']=background
plt.savefig("pepe_20",bbox_inches="tight",dpi=300);

# %%
cont = pd.read_html('https://fbref.com/en/comps/Big5/2018-2019/stats/players/2018-2019-Big-5-European-Leagues-Stats')[0]

# %%
def drop_header(df):
    my_df = df.copy()
    my_df = my_df.droplevel(0, axis=1)
    return(my_df)

# %%
cont = drop_header(cont)

# %%
def cleaner(df):
    all_columns = list(df.columns)
    unwanted_columns = {'Player','Comp'}
    index_columns = [ele for ele in all_columns if ele not in unwanted_columns]
    num_df = df.loc[:,index_columns].apply(pd.to_numeric, errors='coerce')
    num_df.fillna(0, inplace=True)
    master_df = pd.concat([df[['Player', 'Comp']], num_df], axis = 1)
    return master_df

# %%
cont = cleaner(cont)

# %%
mask = cont['G+A'] > 0
cont = cont.loc[mask]

# %%
mask2=(cont['Player']=='Nicolas Pépé')
pepe=cont[mask2]
pepe
# Out:
#             Player        Comp      Rk  Nation  Pos  Squad   Age    Born  \
# 1986  Nicolas Pépé  fr Ligue 1  1911.0     0.0  0.0    0.0  23.0  1995.0
#
#         MP  Starts     Min   Gls  Gls   Ast  Ast   PK  PKatt  CrdY  CrdR  \
# 1986  38.0    37.0  3324.0  22.0  0.6  11.0  0.3  9.0   10.0   1.0   0.0
#
#        Gls  Gls   Ast  Ast   G+A  G-PK  G+A-PK    xG    xG  npxG  npxG   xA  \
# 1986  22.0  0.6  11.0  0.3  0.89  0.35    0.65  21.0  0.57  13.4  0.36  8.3
#
#         xA    xG    xG   xA    xA  xG+xA  npxG  npxG  npxG+xA  Matches
# 1986  0.23  21.0  0.57  8.3  0.23   0.79  13.4  0.36     0.59      0.0

# %%
cont
# Out:
#                    Player                Comp      Rk  Nation  Pos  Squad  \
# 1     Patrick van Aanholt  eng Premier League     2.0     0.0  0.0    0.0
# 5             Mehdi Abeid          fr Ligue 1     6.0     0.0  0.0    0.0
# 9        Francesco Acerbi          it Serie A    10.0     0.0  0.0    0.0
# 10         Afriyie Acquah          it Serie A    11.0     0.0  0.0    0.0
# 11            Tyler Adams       de Bundesliga    12.0     0.0  0.0    0.0
# ...                   ...                 ...     ...     ...  ...    ...
# 2756         Steven Zuber       de Bundesliga  2651.0     0.0  0.0    0.0
# 2757         Steven Zuber       de Bundesliga  2652.0     0.0  0.0    0.0
# 2761       David Zurutuza          es La Liga  2656.0     0.0  0.0    0.0
# 2762       Filip Đorđević          it Serie A  2657.0     0.0  0.0    0.0
# 2763        Filip Đuričić          it Serie A  2658.0     0.0  0.0    0.0
#
#        Age    Born    MP  Starts     Min  Gls   Gls  Ast   Ast   PK  PKatt  \
# 1     27.0  1990.0  36.0    36.0  3195.0  3.0  0.08  2.0  0.06  0.0    0.0
# 5     25.0  1992.0  26.0    23.0  2023.0  3.0  0.13  0.0  0.00  1.0    1.0
# 9     30.0  1988.0  37.0    37.0  3309.0  3.0  0.08  1.0  0.03  0.0    0.0
# 10    26.0  1992.0  28.0    19.0  1510.0  2.0  0.12  0.0  0.00  0.0    0.0
# 11    19.0  1999.0  10.0     8.0   721.0  0.0  0.00  2.0  0.25  0.0    0.0
# ...    ...     ...   ...     ...     ...  ...   ...  ...   ...  ...    ...
# 2756  26.0  1991.0   9.0     6.0   571.0  0.0  0.00  1.0  0.16  0.0    0.0
# 2757  26.0  1991.0  13.0    13.0  1051.0  5.0  0.43  1.0  0.09  1.0    1.0
# 2761  32.0  1986.0  21.0    13.0  1222.0  2.0  0.15  0.0  0.00  0.0    0.0
# 2762  30.0  1987.0  13.0     6.0   634.0  1.0  0.14  1.0  0.14  0.0    0.0
# 2763  26.0  1992.0  23.0    16.0  1252.0  2.0  0.14  1.0  0.07  0.0    0.0
#
#       CrdY  CrdR  Gls   Gls  Ast   Ast   G+A  G-PK  G+A-PK   xG    xG  npxG  \
# 1      3.0   0.0  3.0  0.08  2.0  0.06  0.14  0.08    0.14  2.7  0.08   2.7
# 5      6.0   0.0  3.0  0.13  0.0  0.00  0.13  0.09    0.09  3.1  0.14   2.3
# 9      4.0   1.0  3.0  0.08  1.0  0.03  0.11  0.08    0.11  3.0  0.08   3.0
# 10     4.0   0.0  2.0  0.12  0.0  0.00  0.12  0.12    0.12  1.5  0.09   1.5
# 11     0.0   0.0  0.0  0.00  2.0  0.25  0.25  0.00    0.25  0.2  0.03   0.2
# ...    ...   ...  ...   ...  ...   ...   ...   ...     ...  ...   ...   ...
# 2756   1.0   0.0  0.0  0.00  1.0  0.16  0.16  0.00    0.16  0.7  0.11   0.7
# 2757   3.0   0.0  5.0  0.43  1.0  0.09  0.51  0.34    0.43  2.5  0.22   1.8
# 2761   2.0   0.0  2.0  0.15  0.0  0.00  0.15  0.15    0.15  1.5  0.11   1.5
# 2762   1.0   0.0  1.0  0.14  1.0  0.14  0.28  0.14    0.28  2.7  0.38   2.7
# 2763   2.0   1.0  2.0  0.14  1.0  0.07  0.22  0.14    0.22  1.4  0.10   1.4
#
#       npxG   xA    xA   xG    xG   xA    xA  xG+xA  npxG  npxG  npxG+xA  \
# 1     0.08  3.9  0.11  2.7  0.08  3.9  0.11   0.19   2.7  0.08     0.19
# 5     0.10  1.5  0.06  3.1  0.14  1.5  0.06   0.20   2.3  0.10     0.17
# 9     0.08  0.6  0.02  3.0  0.08  0.6  0.02   0.10   3.0  0.08     0.10
# 10    0.09  0.6  0.04  1.5  0.09  0.6  0.04   0.13   1.5  0.09     0.13
# 11    0.03  0.7  0.09  0.2  0.03  0.7  0.09   0.12   0.2  0.03     0.12
# ...    ...  ...   ...  ...   ...  ...   ...    ...   ...   ...      ...
# 2756  0.11  1.5  0.23  0.7  0.11  1.5  0.23   0.34   0.7  0.11     0.34
# 2757  0.15  2.0  0.17  2.5  0.22  2.0  0.17   0.39   1.8  0.15     0.33
# 2761  0.11  0.3  0.02  1.5  0.11  0.3  0.02   0.14   1.5  0.11     0.14
# 2762  0.38  0.4  0.06  2.7  0.38  0.4  0.06   0.44   2.7  0.38     0.44
# 2763  0.10  1.1  0.08  1.4  0.10  1.1  0.08   0.18   1.4  0.10     0.18
#
#       Matches
# 1         0.0
# 5         0.0
# 9         0.0
# 10        0.0
# 11        0.0
# ...       ...
# 2756      0.0
# 2757      0.0
# 2761      0.0
# 2762      0.0
# 2763      0.0
#
# [1641 rows x 41 columns]

# %%
cont = cont[['Player', 'Nation','Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP', 'G+A']]

# %%
# Drop columns
df1 = cont.drop(['Player', 'Nation','Pos', 'Squad', 'Comp', 'Age', 'Born', 'MP'], axis=1)

# %%
DFNom=df1.rank(pct=True)

# %%
# #Normalize data
# DFNom = df1.transform(lambda x: (x - x.min())/ (x.max() - x.min()))

# %%
DFNom
# Out:
#            G+A
# 1     0.326021
# 5     0.298598
# 9     0.239793
# 10    0.271176
# 11    0.558501
# ...        ...
# 2756  0.386350
# 2757  0.847044
# 2761  0.359232
# 2762  0.606033
# 2763  0.503047
#
# [1641 rows x 1 columns]

# %%
master_df = pd.concat([cont[['Player','Pos','Squad','Comp','Age']], DFNom], axis = 1)
master_df
# Out:
#                    Player  Pos  Squad                Comp   Age       G+A
# 1     Patrick van Aanholt  0.0    0.0  eng Premier League  27.0  0.326021
# 5             Mehdi Abeid  0.0    0.0          fr Ligue 1  25.0  0.298598
# 9        Francesco Acerbi  0.0    0.0          it Serie A  30.0  0.239793
# 10         Afriyie Acquah  0.0    0.0          it Serie A  26.0  0.271176
# 11            Tyler Adams  0.0    0.0       de Bundesliga  19.0  0.558501
# ...                   ...  ...    ...                 ...   ...       ...
# 2756         Steven Zuber  0.0    0.0       de Bundesliga  26.0  0.386350
# 2757         Steven Zuber  0.0    0.0       de Bundesliga  26.0  0.847044
# 2761       David Zurutuza  0.0    0.0          es La Liga  32.0  0.359232
# 2762       Filip Đorđević  0.0    0.0          it Serie A  30.0  0.606033
# 2763        Filip Đuričić  0.0    0.0          it Serie A  26.0  0.503047
#
# [1641 rows x 6 columns]

# %%
hist = np.histogram(master_df['G+A'], bins=100)

# %%
y_offset = 1
xdf = []
ydf = []
x = 0
for n in hist[0]:
    if (n % 2) == 0:
        half = int(n / 2)
    else:
        half = int((n - 1) / 2)
        xdf.append(x)
        ydf.append(0)
    for y in range(0, half):
        xdf.append(x)
        ydf.append(y * y_offset)
    for y in range(0, half):
        xdf.append(x)
        ydf.append(-1 * y * y_offset)
    x = x + 1

plt.scatter(xdf, ydf, marker="o", s=10);
