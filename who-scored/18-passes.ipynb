# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.patches as patches
warnings.filterwarnings("ignore")

# %%
passData = pd.read_csv('./auba_goal.csv')

# %%
#convert pitch measurements OPTA
passData['xM'] = passData.X / 100 * 104
passData['yM'] = passData.Y / 100 * 68
passData['xE'] = passData.endX / 100 * 104
passData['yE'] = passData.endY / 100 * 68

# %%
pass_df = passData['Event'] == 'Pass'
pss = passData[pass_df][:1]
pss
# Out:
#   Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 1  Pass      17    12.0   89401    13  Successful  12.4  37.0  23.0  34.6
#
#        xM     yM     xE      yE
# 1  12.896  25.16  23.92  23.528

# %%
pass_df = passData['Event'] == 'Pass'
pss1 = passData[pass_df][1:2]
pss1
# Out:
#   Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 2  Pass      17    15.0   73078    13  Successful  23.8  32.8  21.6  28.4
#
#        xM      yM      xE      yE
# 2  24.752  22.304  22.464  19.312

# %%
pass_df = passData['Event'] == 'Pass'
pss2 = passData[pass_df][2:5]
pss2
# Out:
#   Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 3  Pass      17    17.0   89401    13  Successful  22.1  26.9  19.5   9.2
# 4  Pass      17    19.0  125211    13  Successful  19.4   8.5  21.1  24.1
# 5  Pass      17    21.0  144890    13  Successful  22.6  25.0  10.8  24.7
#
#        xM      yM      xE      yE
# 3  22.984  18.292  20.280   6.256
# 4  20.176   5.780  21.944  16.388
# 5  23.504  17.000  11.232  16.796

# %%
pass_df = passData['Event'] == 'Pass'
pss3 = passData[pass_df][5:6]
pss3
# Out:
#   Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 6  Pass      17    24.0   80921    13  Successful  10.8  25.0   4.6  47.8
#
#        xM    yM     xE      yE
# 6  11.232  17.0  4.784  32.504

# %%
pass_df = passData['Event'] == 'Pass'
pss4 = passData[pass_df][6:9]
pss4
# Out:
#   Event  Minute  Second  Player  Team     Outcome    X     Y  endX  endY  \
# 7  Pass      17    27.0  102248    13  Successful  4.3  52.5   8.2  59.1
# 8  Pass      17    28.0   27586    13  Successful  8.2  58.5   4.4  52.2
# 9  Pass      17    30.0  102248    13  Successful  4.4  52.2  14.6  49.6
#
#       xM      yM      xE      yE
# 7  4.472  35.700   8.528  40.188
# 8  8.528  39.780   4.576  35.496
# 9  4.576  35.496  15.184  33.728

# %%
pass_df = passData['Event'] == 'Pass'
pss5 = passData[pass_df][9:10]
pss5
# Out:
#    Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 10  Pass      17    33.0  144890    13  Successful  12.0  44.6   3.7  23.8
#
#        xM      yM     xE      yE
# 10  12.48  30.328  3.848  16.184

# %%
pass_df = passData['Event'] == 'Pass'
pss6 = passData[pass_df][10:11]
pss6
# Out:
#    Event  Minute  Second  Player  Team     Outcome    X     Y  endX  endY  \
# 11  Pass      17    36.0   80921    13  Successful  3.7  27.2   2.2  42.2
#
#        xM      yM     xE      yE
# 11  3.848  18.496  2.288  28.696

# %%
pass_df = passData['Event'] == 'Pass'
pss7 = passData[pass_df][11:12]
pss7
# Out:
#    Event  Minute  Second  Player  Team     Outcome    X     Y  endX  endY  \
# 12  Pass      17    39.0  102248    13  Successful  2.1  42.5  11.7  47.6
#
#        xM    yM      xE      yE
# 12  2.184  28.9  12.168  32.368

# %%
pass_df = passData['Event'] == 'Pass'
pss8 = passData[pass_df][12:13]
pss8
# Out:
#    Event  Minute  Second  Player  Team     Outcome    X     Y  endX  endY  \
# 13  Pass      17    44.0   89401    13  Successful  9.4  48.0  10.5  77.1
#
#        xM     yM     xE      yE
# 13  9.776  32.64  10.92  52.428

# %%
pass_df = passData['Event'] == 'Pass'
pss9 = passData[pass_df][13:14]
pss9
# Out:
#    Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 14  Pass      17    46.0   27586    13  Successful  29.4  75.8  39.4  96.9
#
#         xM      yM      xE      yE
# 14  30.576  51.544  40.976  65.892

# %%
pass_df = passData['Event'] == 'Pass'
pss10 = passData[pass_df][14:16]
pss10
# Out:
#    Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 15  Pass      17    49.0  297403    13  Successful  44.5  97.7  58.0  75.9
# 16  Pass      17    51.0   73078    13  Successful  54.2  65.4  56.0  28.1
#
#         xM      yM     xE      yE
# 15  46.280  66.436  60.32  51.612
# 16  56.368  44.472  58.24  19.108

# %%
pass_df = passData['Event'] == 'Pass'
pss11 = passData[pass_df][16:17]
pss11
# Out:
#    Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 17  Pass      17    57.0  125211    13  Successful  74.9  22.0  85.9  13.7
#
#         xM     yM      xE     yE
# 17  77.896  14.96  89.336  9.316

# %%
pass_df = passData['Event'] == 'Pass'
pss12 = passData[pass_df][17:]
pss12
# Out:
#    Event  Minute  Second  Player  Team     Outcome     X     Y  endX  endY  \
# 18  Pass      17    59.0  239872    13  Successful  82.8  14.3  95.9  59.0
#
#         xM     yM      xE     yE
# 18  86.112  9.724  99.736  40.12

# %%
draw_pitch(pitch ='#252932', line ='#696969',orientation='horizontal', view='full')

csfont = {'fontname':'BBC Reith Sans'}
hfont = {'fontname':'BBC Reith Sans'}

wedge="wedge,tail_width=0.3"
arrow="Simple,tail_width=0.05,head_width=0.15,head_length=0.01"
arrow2="Simple,tail_width=0.05,head_width=0.7,head_length=0.7"
arrow3="Simple,tail_width=0.05,head_width=0.45,head_length=.45"

x = pss.xM.values
y = pss.yM.values
xE = pss.xE.values
yE = pss.yE.values

plt.scatter(x,y,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE,yE,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.4)

for i in range(len(pss)):
    plt.annotate('', xy=(xE[i],yE[i]), xytext=(x[i],y[i]), zorder=7, arrowprops=dict(arrowstyle=arrow2,shrinkA=7, shrinkB=7.3, lw=0.1,color='#66FF00',alpha=0.9))
    
arrow1="Simple,tail_width=0.01,head_width=0.2,head_length=0.2"

x1 = pss1.xM.values
y1 = pss1.yM.values
xE1 = pss1.xE.values
yE1 = pss1.yE.values

plt.scatter(x1,y1,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE1,yE1,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)

for i in range(len(pss1)):
    plt.annotate('', xy=(xE1[i],yE1[i]), xytext=(x1[i],y1[i]), zorder=13, arrowprops=dict(arrowstyle=arrow1,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))

x2 = pss2.xM.values
y2 = pss2.yM.values
xE2 = pss2.xE.values
yE2 = pss2.yE.values

plt.scatter(x2,y2,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.2)
plt.scatter(xE2,yE2,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)

for i in range(len(pss2)):
    plt.annotate('', xy=(xE2[i],yE2[i]), xytext=(x2[i],y2[i]), zorder=7, arrowprops=dict(arrowstyle=arrow3,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))

    
x3 = pss3.xM.values
y3 = pss3.yM.values
xE3 = pss3.xE.values
yE3 = pss3.yE.values

plt.scatter(x3,y3,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE3,yE3,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.4)

for i in range(len(pss3)):
    plt.annotate('', xy=(xE3[i],yE3[i]), xytext=(x3[i],y3[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))

x4 = pss4.xM.values
y4 = pss4.yM.values
xE4 = pss4.xE.values
yE4 = pss4.yE.values

plt.scatter(x4,y4,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.4)
plt.scatter(xE4,yE4,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)

for i in range(len(pss4)):
    plt.annotate('', xy=(xE4[i],yE4[i]), xytext=(x4[i],y4[i]), zorder=7, arrowprops=dict(arrowstyle=arrow3,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))

x5 = pss5.xM.values
y5 = pss5.yM.values
xE5 = pss5.xE.values
yE5 = pss5.yE.values

plt.scatter(x5,y5,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE5,yE5,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.4)

for i in range(len(pss5)):
    plt.annotate('', xy=(xE5[i],yE5[i]), xytext=(x5[i],y5[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=14,lw=0.1,color='#66FF00',alpha=0.9))

x6 = pss6.xM.values
y6 = pss6.yM.values
xE6 = pss6.xE.values
yE6 = pss6.yE.values

plt.scatter(x6,y6,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE6,yE6,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)

for i in range(len(pss6)):
    plt.annotate('', xy=(xE6[i],yE6[i]), xytext=(x6[i],y6[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=7.2,lw=0.1,color='#66FF00',alpha=0.9))
    
x7 = pss7.xM.values
y7 = pss7.yM.values
xE7 = pss7.xE.values
yE7 = pss7.yE.values

plt.scatter(x7,y7,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE7,yE7,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.1)

for i in range(len(pss7)):
    plt.annotate('', xy=(xE7[i],yE7[i]), xytext=(x7[i],y7[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=16.1,lw=0.1,color='#66FF00',alpha=0.9))
    
x8 = pss8.xM.values
y8 = pss8.yM.values
xE8 = pss8.xE.values
yE8 = pss8.yE.values

plt.scatter(x8,y8,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE8,yE8,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.4)

for i in range(len(pss8)):
    plt.annotate('', xy=(xE8[i],yE8[i]), xytext=(x8[i],y8[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))
    
x9 = pss9.xM.values
y9 = pss9.yM.values
xE9 = pss9.xE.values
yE9 = pss9.yE.values

plt.scatter(x9,y9,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE9,yE9,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.3)

for i in range(len(pss9)):
    plt.annotate('', xy=(xE9[i],yE9[i]), xytext=(x9[i],y9[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))

x10 = pss10.xM.values
y10 = pss10.yM.values
xE10 = pss10.xE.values
yE10 = pss10.yE.values

plt.scatter(x10,y10,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE10,yE10,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.3)

for i in range(len(pss10)):
    plt.annotate('', xy=(xE10[i],yE10[i]), xytext=(x10[i],y10[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))
    
x11 = pss11.xM.values
y11 = pss11.yM.values
xE11 = pss11.xE.values
yE11 = pss11.yE.values

plt.scatter(x11,y11,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE11,yE11,color="#DB0007",edgecolors="white", s=200, linewidth=0.5, zorder=12, alpha=0.3)

for i in range(len(pss11)):
    plt.annotate('', xy=(xE11[i],yE11[i]), xytext=(x11[i],y11[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=7,lw=0.1,color='#66FF00',alpha=0.9))


x12 = pss12.xM.values
y12 = pss12.yM.values
xE12 = pss12.xE.values
yE12 = pss12.yE.values

plt.scatter(x12,y12,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)
plt.scatter(xE12,yE12,color="#DB0007",edgecolors="white", s=200, linewidth=1, zorder=12, alpha=0.8)

for i in range(len(pss12)):
    plt.annotate('', xy=(xE12[i],yE12[i]), xytext=(x12[i],y12[i]), zorder=7, arrowprops=dict(arrowstyle=arrow,shrinkA=7, shrinkB=7.3,lw=0.1,color='#66FF00',alpha=0.9))

    

    
plt.text(11.75,24.5, "34", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(14,26.5, "Xhaka interception\nstarts the sequence", color='white',fontsize=6, **csfont, zorder=20,style='italic')
plt.text(24.2,21.7, "9", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(21.3,18.6, "34", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(19.6,5.5, "2", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(21.3,15.7, "8", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(10.1,16.3, "20", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(1.1,28.1, "26", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(3.4,35, "26", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
# plt.text(3.65,31.85, "26", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold",alpha=0.7)
plt.text(7.4,39.5, "23", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(14.5,33, "8", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(8.6,31.9, "34", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(2.8,17.9, "20", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(11.9,29.7, "8", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
# plt.text(9.8,51.8, "23", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(29.4,51, "23", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
# plt.text(40.3,65.2, "3", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(45.7,65.8, "3", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
# plt.text(60,51, "9", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(55.8,43.9, "9", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
# plt.text(57.5,18.7, "2", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(77.3,14.4, "2", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(85,9, "19", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")
plt.text(98.5,39.4, "14", color='white',fontsize=10, **csfont, zorder=15, fontweight="bold")

plt.plot([12.2,30],[52.3,51.8],color="#66FF00",zorder=3, alpha=1, ls="--",lw=0.8, dashes=(5, 5))
plt.plot([42.1,45],[66,66.2],color="#66FF00",zorder=3, alpha=1, ls="--",lw=0.8, dashes=(5, 5))
plt.plot([60.1,55.8],[50,43.9],color="#66FF00",zorder=3, alpha=1, ls="--",lw=0.8, dashes=(5, 5))
plt.plot([60,79],[18.9,14.5],color="#66FF00",zorder=3, alpha=1, ls="--",lw=0.8, dashes=(5, 5))
plt.plot([14.5,11.9],[32,29.7],color="#66FF00",zorder=3, alpha=1, ls="--",lw=0.8, dashes=(5, 55))
plt.annotate('',(100,41),(104.5,30), zorder=15, arrowprops=dict(arrowstyle=wedge,lw=0.1,color='#66FF00',alpha=0.9))

#title
plt.text(0,72, "Arsenal", color='#ffffff',fontsize=20, fontweight='bold', **csfont)
subtitle_string = 'vs. Manchester City | FA Cup Semi-Final | Season 2019/2020'
plt.text(0, 69.5, subtitle_string, fontsize=9,**csfont, color='#ffffff')
plt.figimage(img, 1540, 1073.5, alpha=.9, zorder=1)

info_string = '@jonollington'
plt.text(93, -3, info_string, color='#ffffff', ha='left', va='bottom', fontsize=8, **csfont)

info_string = 'Dotted line indicates ball being carried from shaded point. Straight-line indicates a pass. Numbers indicate shirt numbers.'
plt.text(0, -3, info_string, color='white', ha='left', va='bottom', fontsize=6, **csfont, style='italic')
    
plt.rcParams['axes.facecolor']='#252932'
plt.rcParams['savefig.facecolor']='#252932'

plt.savefig("Auba",bbox_inches="tight",dpi=200);

# %%
def draw_pitch(pitch, line, orientation, view):
     
    orientation = orientation
    view = view
    line = line
    pitch = pitch
     
    if orientation.lower().startswith("h"):
         
        if view.lower().startswith("h"):
            fig,ax = plt.subplots(figsize=(6.8,10.4))
            plt.xlim(49,105)
            plt.ylim(-1,69)
        elif view.lower().startswith("t"):
            fig,ax = plt.subplots(figsize=(6.8,10.4))
            plt.xlim(69,105)
            plt.ylim(-1,69)
            # final third line
            lxt = [0,68] 
            lyt = [69,69]
            plt.plot(lxt,lyt,color=line,linestyle='--',zorder=5)
        else:
            fig,ax = plt.subplots(figsize=(10.4,6.8))
            plt.xlim(-1,105)
            plt.ylim(-1,69)
        ax.axis('off') # this hides the x and y ticks
     
        # side and goal lines #
        ly1 = [0,0,68,68,0]
        lx1 = [0,104,104,0,0]
 
        plt.plot(lx1,ly1,color=line,zorder=5)
 
 
        # boxes, 6 yard box and goals
 
            #outer boxes#
        ly2 = [13.84,13.84,54.16,54.16] 
        lx2 = [104,87.5,87.5,104]
        plt.plot(lx2,ly2,color=line,zorder=5)
 
        ly3 = [13.84,13.84,54.16,54.16] 
        lx3 = [0,16.5,16.5,0]
        plt.plot(lx3,ly3,color=line,zorder=5)
 
            #goals#
        ly4 = [30.34,30.34,37.66,37.66]
        lx4 = [104,104.2,104.2,104]
        plt.plot(lx4,ly4,color=line,zorder=5)
 
        ly5 = [30.34,30.34,37.66,37.66]
        lx5 = [0,-0.2,-0.2,0]
        plt.plot(lx5,ly5,color=line,zorder=5)
 
 
           #6 yard boxes#
        ly6 = [24.84,24.84,43.16,43.16]
        lx6 = [104,99.5,99.5,104]
        plt.plot(lx6,ly6,color=line,zorder=5)
 
        ly7 = [24.84,24.84,43.16,43.16]
        lx7 = [0,4.5,4.5,0]
        plt.plot(lx7,ly7,color=line,zorder=5)
 
        #Halfway line, penalty spots, and kickoff spot
        ly8 = [0,68] 
        lx8 = [52,52]
        plt.plot(lx8,ly8,color=line,zorder=5)
 
 
        plt.scatter(93,34,color=line,zorder=5)
        plt.scatter(11,34,color=line,zorder=5)
        plt.scatter(52,34,color=line,zorder=5)
 
        circle1 = plt.Circle((93.5,34), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle2 = plt.Circle((10.5,34), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle3 = plt.Circle((52, 34), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=2,alpha=1)
 
        ## Rectangles in boxes
        rec1 = plt.Rectangle((87.5,20), 16,30,ls='-',color=pitch, zorder=1,alpha=1)
        rec2 = plt.Rectangle((0, 20), 16.5,30,ls='-',color=pitch, zorder=1,alpha=1)
 
        ## Pitch rectangle
        rec3 = plt.Rectangle((-1, -1), 106,70,ls='-',color=pitch, zorder=1,alpha=1)
 
        ax.add_artist(rec3)
        ax.add_artist(circle1)
        ax.add_artist(circle2)
        ax.add_artist(rec1)
        ax.add_artist(rec2)
        ax.add_artist(circle3)
         
    else:
        if view.lower().startswith("h"):
            fig,ax = plt.subplots(figsize=(10.4,6.8))
            plt.ylim(49,105)
            plt.xlim(-1,69)
        elif view.lower().startswith("t"):
            fig,ax = plt.subplots(figsize=(10.4,6.8))
            plt.ylim(69,105)
            plt.xlim(-1,69)
            # final third line
            lxt = [0,68] 
            lyt = [69,69]
            plt.plot(lxt,lyt,color=line,linestyle='--',zorder=5)
        else:
            fig,ax = plt.subplots(figsize=(6.8,10.4))
            plt.ylim(-1,105)
            plt.xlim(-1,69)
        ax.axis('off') # this hides the x and y ticks
 
        # side and goal lines #
        lx1 = [0,0,68,68,0]
        ly1 = [0,104,104,0,0]
 
        plt.plot(lx1,ly1,color=line,zorder=5)
 
 
        # boxes, 6 yard box and goals
 
            #outer boxes#
        lx2 = [13.84,13.84,54.16,54.16] 
        ly2 = [104,87.5,87.5,104]
        plt.plot(lx2,ly2,color=line,zorder=5)
 
        lx3 = [13.84,13.84,54.16,54.16] 
        ly3 = [0,16.5,16.5,0]
        plt.plot(lx3,ly3,color=line,zorder=5)
 
            #goals#
        lx4 = [30.34,30.34,37.66,37.66]
        ly4 = [104,104.2,104.2,104]
        plt.plot(lx4,ly4,color=line,zorder=5)
 
        lx5 = [30.34,30.34,37.66,37.66]
        ly5 = [0,-0.2,-0.2,0]
        plt.plot(lx5,ly5,color=line,zorder=5)
 
 
           #6 yard boxes#
        lx6 = [24.84,24.84,43.16,43.16]
        ly6 = [104,99.5,99.5,104]
        plt.plot(lx6,ly6,color=line,zorder=5)
 
        lx7 = [24.84,24.84,43.16,43.16]
        ly7 = [0,4.5,4.5,0]
        plt.plot(lx7,ly7,color=line,zorder=5)
 
        #Halfway line, penalty spots, and kickoff spot
        lx8 = [0,68] 
        ly8 = [52,52]
        plt.plot(lx8,ly8,color=line,zorder=5)
 
 
        plt.scatter(34,93,color=line,zorder=5)
        plt.scatter(34,11,color=line,zorder=5)
        plt.scatter(34,52,color=line,zorder=5)
 
        circle1 = plt.Circle((34,93.5), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle2 = plt.Circle((34,10.5), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=1,alpha=1)
        circle3 = plt.Circle((34,52), 9.15,ls='solid',lw=1.5,color=line, fill=False, zorder=2,alpha=1)
 
 
        ## Rectangles in boxes
        rec1 = plt.Rectangle((20, 87.5), 30,16.5,ls='-',color=pitch, zorder=1,alpha=1)
        rec2 = plt.Rectangle((20, 0), 30,16.5,ls='-',color=pitch, zorder=1,alpha=1)
 
        ## Pitch rectangle
        rec3 = plt.Rectangle((-1, -1), 70,106,ls='-',color=pitch, zorder=1,alpha=1)
 
        ax.add_artist(rec3)
        ax.add_artist(circle1)
        ax.add_artist(circle2)
        ax.add_artist(rec1)
        ax.add_artist(rec2)
        ax.add_artist(circle3)
        return

# %%
from PIL import Image

# %%
img = Image.open('./Arsenal.png')
img.size
# Out:
# (411, 481)

# %%
img = img.resize((82, 96), Image.ANTIALIAS)
