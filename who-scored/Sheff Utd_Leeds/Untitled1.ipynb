# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.patches as patches
warnings.filterwarnings("ignore")
from mplsoccer.pitch import Pitch
plt.style.use('ggplot')
from PIL import Image
from highlight_text import htext

# %%
with open('Arsenal_Sheff Utd.json') as json_file:
    data = json.load(json_file)
    
event = []
minute = []
second = []
player = []
team = []
outcome = []
x = []
y = []
endX = []
endY = []

for each in data['events']:
    event.append(each['type']['displayName'])
    try:
        minute.append(each['minute'])
    except:
        minute.append('')
    try:
        second.append(each['second'])
    except:
        second.append('')
    try:
        player.append(each['playerId'])
    except:
        player.append('')
    try:
        team.append(each['teamId'])
    except:
        team.append('')
    try:
        endX.append(each['endX'])
        endY.append(each['endY'])
    except:
        endX.append('')
        endY.append('')
    outcome.append(each['outcomeType']['displayName'])
    x.append(each['x'])
    y.append(each['y'])

events = pd.DataFrame({'Event':event, 'Minute':minute, 'Second':second, 'Player':player, 'Team':team, 'Outcome':outcome, 'x':x, 'y':y,
                      'endX':endX, 'endY':endY})

# %%
events["Second"] = pd.to_numeric(events["Second"])
events["endX"] = pd.to_numeric(events["endX"])
events["endY"] = pd.to_numeric(events["endY"])

# %%
mask = ((events['Minute'] > 61) & (events['Second'] > 2)) & (events['Minute'] < 64)
pepe = events.loc[mask].copy()
pepe.Event.value_counts()
# Out:
# Pass    18
# Goal     1
# Name: Event, dtype: int64

# %%
pass_df = pepe['Event'] == 'Pass'
pss0 = pepe[pass_df][:1]
pss0
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x    y  endX  endY
# 1011  Pass      62    24.0  125211    13  Successful  23.7  0.0  13.4   7.3

# %%
pass_df = pepe['Event'] == 'Pass'
pss1 = pepe[pass_df][1:2]
pss1
# Out:
#      Event  Minute  Second Player  Team     Outcome     x    y  endX  endY
# 1012  Pass      62    26.0  27586    13  Successful  13.3  7.9   7.0  41.0

# %%
pass_df = pepe['Event'] == 'Pass'
pss2 = pepe[pass_df][2:3]
pss2
# Out:
#      Event  Minute  Second Player  Team     Outcome     x     y  endX  endY
# 1013  Pass      62    30.0  92173    13  Successful  11.5  48.5  23.7  83.3

# %%
pass_df = pepe['Event'] == 'Pass'
pss3 = pepe[pass_df][3:4]
pss3
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1014  Pass      62    34.0  297403    13  Successful  32.1  90.3  32.9  82.6

# %%
pass_df = pepe['Event'] == 'Pass'
pss4 = pepe[pass_df][4:5]
pss4
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1015  Pass      62    37.0  144890    13  Successful  33.3  81.5  30.5  92.1

# %%
pass_df = pepe['Event'] == 'Pass'
pss5 = pepe[pass_df][5:6]
pss5
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1016  Pass      62    37.0  297403    13  Successful  30.5  92.1  23.3  76.3

# %%
pass_df = pepe['Event'] == 'Pass'
pss6 = pepe[pass_df][6:7]
pss6
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1017  Pass      62    41.0  334087    13  Successful  23.6  73.3  20.5  40.0

# %%
pass_df = pepe['Event'] == 'Pass'
pss7 = pepe[pass_df][7:8]
pss7
# Out:
#      Event  Minute  Second Player  Team     Outcome     x     y  endX  endY
# 1018  Pass      62    46.0  27586    13  Successful  25.4  49.7  30.9  71.4

# %%
pass_df = pepe['Event'] == 'Pass'
pss8 = pepe[pass_df][8:9]
pss8
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1019  Pass      62    49.0  334087    13  Successful  36.6  78.7  52.8  91.4

# %%
pass_df = pepe['Event'] == 'Pass'
pss9 = pepe[pass_df][9:10]
pss9
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1020  Pass      62    51.0  297403    13  Successful  53.1  91.4  52.8  81.5

# %%
pass_df = pepe['Event'] == 'Pass'
pss10 = pepe[pass_df][10:11]
pss10
# Out:
#      Event  Minute  Second Player  Team     Outcome     x     y  endX  endY
# 1021  Pass      62    53.0  29463    13  Successful  52.8  81.5  52.2  93.0

# %%
pass_df = pepe['Event'] == 'Pass'
pss11 = pepe[pass_df][11:12]
pss11
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1022  Pass      62    54.0  297403    13  Successful  52.2  93.0  36.7  84.7

# %%
pass_df = pepe['Event'] == 'Pass'
pss12 = pepe[pass_df][12:13]
pss12
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1023  Pass      62    56.0  334087    13  Successful  36.6  80.2  32.3  52.4

# %%
pass_df = pepe['Event'] == 'Pass'
pss13 = pepe[pass_df][13:14]
pss13
# Out:
#      Event  Minute  Second Player  Team     Outcome     x     y  endX  endY
# 1024  Pass      62    58.0  27586    13  Successful  32.0  52.8  32.4  73.5

# %%
pass_df = pepe['Event'] == 'Pass'
pss14 = pepe[pass_df][14:15]
pss14
# Out:
#      Event  Minute  Second Player  Team     Outcome     x     y  endX  endY
# 1026  Pass      63     6.0  29463    13  Successful  40.9  72.0  39.4  26.2

# %%
pass_df = pepe['Event'] == 'Pass'
pss15 = pepe[pass_df][15:16]
pss15
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1027  Pass      63    10.0  125209    13  Successful  40.2  21.3  54.3   6.5

# %%
pass_df = pepe['Event'] == 'Pass'
pss16 = pepe[pass_df][16:17]
pss16
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x    y  endX  endY
# 1028  Pass      63    11.0  239872    13  Successful  54.3  6.5  58.7  18.8

# %%
pass_df = pepe['Event'] == 'Pass'
pss17 = pepe[pass_df][17:18]
pss17
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1029  Pass      63    13.0  125211    13  Successful  58.8  19.1  70.3  13.7

# %%
pass_df = pepe['Event'] == 'Goal'
pss18 = pepe[pass_df]
pss18
# Out:
#      Event  Minute  Second  Player  Team     Outcome     x     y  endX  endY
# 1030  Goal      63    18.0  239872    13  Successful  86.7  37.1   NaN   NaN

# %%
team = "Arsenal"
oppo1 = "Liverpool"
oppo2 = "Fulham"
background = "#313332"
line = '#696969'
title_font = "BBC Reith Sans"
body_font = "BBC Reith Sans"
text_color = "w"
primary = "red"

pitch = Pitch(figsize=(15,15),orientation='horizontal',view='full',layout=(1, 1),goal_type='box',pitch_type='opta',
              pitch_color=background, line_color=line,constrained_layout=False)

fig, ax = pitch.draw()

x = pss0.x.values
y = pss0.y.values
xE = pss0.endX.values
yE = pss0.endY.values
ax.scatter(y,x,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax.scatter(yE,xE,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss0)):
    ax.annotate('', xy=(yE[i],xE[i]), xytext=(y[i],x[i]), zorder=7, arrowprops=dict(arrowstyle='->',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))

x1 = pss1.x.values
y1 = pss1.y.values
xE1 = pss1.endX.values
yE1 = pss1.endY.values
ax.scatter(y1,x1,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax.scatter(yE1,xE1,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss1)):
    ax.annotate('', xy=(yE1[i],xE1[i]), xytext=(y1[i],x1[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))
    
x2 = pss2.x.values
y2 = pss2.y.values
xE2 = pss2.endX.values
yE2 = pss2.endY.values
ax.scatter(y2,x2,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax.scatter(yE2,xE2,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss2)):
    ax.annotate('', xy=(yE2[i],xE2[i]), xytext=(y2[i],x2[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))
    
x3 = pss3.x.values
y3 = pss3.y.values
xE3 = pss3.endX.values
yE3 = pss3.endY.values

ax.scatter(y3,x3,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax.scatter(yE3,xE3,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)

for i in range(len(pss3)):
    ax.annotate('', xy=(yE3[i],xE3[i]), xytext=(y3[i],x3[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))    

x4 = pss4.x.values
y4 = pss4.y.values
xE4 = pss4.endX.values
yE4 = pss4.endY.values

ax.scatter(y4,x4,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE4,xE4,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)

for i in range(len(pss4)):
    ax[0].annotate('', xy=(yE4[i],xE4[i]), xytext=(y4[i],x4[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))        

x5 = pss5.x.values
y5 = pss5.y.values
xE5 = pss5.endX.values
yE5 = pss5.endY.values
ax[0].scatter(y5,x5,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE5,xE5,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss5)):
    ax[0].annotate('', xy=(yE5[i],xE5[i]), xytext=(y5[i],x5[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x6 = pss6.x.values
y6 = pss6.y.values
xE6 = pss6.endX.values
yE6 = pss6.endY.values
ax[0].scatter(y6,x6,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE6,xE6,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss6)):
    ax[0].annotate('', xy=(yE6[i],xE6[i]), xytext=(y6[i],x6[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x7 = pss7.x.values
y7 = pss7.y.values
xE7 = pss7.endX.values
yE7 = pss7.endY.values
ax[0].scatter(y7,x7,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE7,xE7,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss7)):
    ax[0].annotate('', xy=(yE7[i],xE7[i]), xytext=(y7[i],x7[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x8 = pss8.x.values
y8 = pss8.y.values
xE8 = pss8.endX.values
yE8 = pss8.endY.values
ax[0].scatter(y8,x8,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE8,xE8,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss8)):
    ax[0].annotate('', xy=(yE8[i],xE8[i]), xytext=(y8[i],x8[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x9 = pss9.x.values
y9 = pss9.y.values
xE9 = pss9.endX.values
yE9 = pss9.endY.values
ax[0].scatter(y9,x9,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE9,xE9,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss8)):
    ax[0].annotate('', xy=(yE8[i],xE8[i]), xytext=(y8[i],x8[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            


x10 = pss10.x.values
y10 = pss10.y.values
xE10 = pss10.endX.values
yE10 = pss10.endY.values
ax[0].scatter(y10,x10,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE10,xE10,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss10)):
    ax[0].annotate('', xy=(yE10[i],xE10[i]), xytext=(y10[i],x10[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x11 = pss11.x.values
y11 = pss11.y.values
xE11 = pss11.endX.values
yE11 = pss11.endY.values
ax[0].scatter(y11,x11,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE11,xE11,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss11)):
    ax[0].annotate('', xy=(yE11[i],xE11[i]), xytext=(y11[i],x11[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x12 = pss12.x.values
y12 = pss12.y.values
xE12 = pss12.endX.values
yE12 = pss12.endY.values
ax[0].scatter(y12,x12,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE12,xE12,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss8)):
    ax[0].annotate('', xy=(yE12[i],xE12[i]), xytext=(y12[i],x12[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x13 = pss13.x.values
y13 = pss13.y.values
xE13 = pss13.endX.values
yE13 = pss13.endY.values
ax[0].scatter(y13,x13,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE13,xE13,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss13)):
    ax[0].annotate('', xy=(yE13[i],xE13[i]), xytext=(y13[i],x13[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x14 = pss14.x.values
y14 = pss14.y.values
xE14 = pss14.endX.values
yE14 = pss14.endY.values
ax[0].scatter(y14,x14,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE14,xE14,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss14)):
    ax[0].annotate('', xy=(yE14[i],xE14[i]), xytext=(y14[i],x14[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x15 = pss15.x.values
y15 = pss15.y.values
xE15 = pss15.endX.values
yE15 = pss15.endY.values
ax[0].scatter(y15,x15,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE15,xE15,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss15)):
    ax[0].annotate('', xy=(yE15[i],xE15[i]), xytext=(y15[i],x15[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x16 = pss16.x.values
y16 = pss16.y.values
xE16 = pss16.endX.values
yE16 = pss16.endY.values
ax[0].scatter(y16,x16,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE16,xE16,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss16)):
    ax[0].annotate('', xy=(yE16[i],xE16[i]), xytext=(y16[i],x16[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

x17 = pss17.x.values
y17 = pss17.y.values
xE17 = pss17.endX.values
yE17 = pss17.endY.values
ax[0].scatter(y17,x17,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE17,xE17,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss17)):
    ax[0].annotate('', xy=(yE17[i],xE17[i]), xytext=(y17[i],x17[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            
    
x18 = pss18.x.values
y18 = pss18.y.values
xE18 = pss18.endX.values
yE18 = pss18.endY.values
ax[0].scatter(y18,x18,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
ax[0].scatter(yE18,xE18,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
for i in range(len(pss18)):
    ax[0].annotate('', xy=(yE18[i],xE18[i]), xytext=(y18[i],x18[i]), zorder=7, arrowprops=dict(arrowstyle='-',lw=1,color=text_color,alpha=0.9,shrinkA=7, shrinkB=10))            

 
    
# ax[0].plot([2.5,4],[15.5,20],color=text_color,zorder=5, alpha=1, ls="--",lw=1, dashes=(4, 4))
# ax[0].plot([3.5,16.5],[46.5,62],color=text_color,zorder=5, alpha=1, ls="--",lw=1, dashes=(4, 4))
# ax[0].plot([71,83],[82.5,77],color=text_color,zorder=5, alpha=1, ls="--",lw=1, dashes=(4, 4))
# ax[0].annotate('', xy=([46,102]), xytext=([71.77,81.9]), zorder=7, arrowprops=dict(arrowstyle="->",connectionstyle="arc3,rad=0.4",lw=1,color=text_color))

    
s = "{} vs. {}"
htext.fig_htext(s.format(team,oppo1),0.03,0.88,highlight_colors=[primary], highlight_weights=["bold"],string_weight="bold",fontsize=24, fontfamily=title_font,color=text_color)
fig.text(0.03,0.868,"Community Shield | 29 Aug 2020",fontweight="regular", fontsize=14,fontfamily=title_font, color=text_color)

htext.fig_htext(s.format(oppo2,team),0.53,0.88,highlight_colors=[primary], highlight_weights=["bold"],string_weight="bold",fontsize=24, fontfamily=title_font,color=text_color)
fig.text(0.53,0.868,"English Premier League | 12 Sep 2020",fontweight="regular", fontsize=14,fontfamily=title_font, color=text_color)

ax2 = fig.add_axes([0.93,0.855,0.05,0.05]) # badge
ax2.axis("off")
img = Image.open('./Arsenal.png')
ax2.imshow(img)

ax3 = fig.add_axes([0.01,0.115,0.05,0.02])
ax3.axis("off")
ax3.scatter([0.2],[0.05],edgecolors=text_color, s=200, linewidth=2, zorder=12, alpha=1)
fig.text(0.05, 0.12, "player",fontsize=13, fontfamily=body_font, color=text_color)

ax4 = fig.add_axes([0.2,0.115,0.05,0.02])
ax4.axis("off")
ax4.scatter([0.2],[0.05],edgecolors=text_color, s=200, linewidth=2, zorder=12, alpha=0.2)
fig.text(0.24, 0.12, "start of carry",fontsize=13, fontfamily=body_font, color=text_color)

ax5 = fig.add_axes([0.4,0.115,0.05,0.02])
ax5.axis("off")
ax5.plot([0.5,0],[0.5,0.5],color=text_color,zorder=5, alpha=1, ls="--",lw=1,dashes=(4, 4))
fig.text(0.455, 0.12, "carry",fontsize=13, fontfamily=body_font, color=text_color)

ax6 = fig.add_axes([0.6,0.115,0.05,0.02])
ax6.axis("off")
ax6.plot([0.5,0],[0.5,0.5],color=text_color,zorder=5, alpha=1, ls="-",lw=1)
fig.text(0.652, 0.12, "pass",fontsize=13, fontfamily=body_font, color=text_color)

fig.text(0.9, 0.12, "@jonollington",fontsize=14, fontfamily=body_font, color=text_color)

plt.rcParams['axes.facecolor']=background
plt.rcParams['savefig.facecolor']=background
plt.savefig("spot",bbox_inches="tight",dpi=200);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-432c2d3792f7> in <module>
#     122 xE11 = pss11.endX.values
#     123 yE11 = pss11.endY.values
# --> 124 ax[0].scatter(y11,x11,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=1)
#     125 ax[0].scatter(yE11,xE11,color="#DB0007",edgecolors=text_color, s=400, linewidth=2, zorder=12, alpha=0.2)
#     126 for i in range(len(pss11)):
#
# TypeError: 'AxesSubplot' object is not subscriptable
