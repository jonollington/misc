# %%
import pandas as pd
import numpy as np
from pandas.io.json import json_normalize
import json
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import matplotlib.patches as patches
warnings.filterwarnings("ignore")
from mplsoccer.pitch import Pitch
plt.style.use('ggplot')
from PIL import Image
from highlight_text import htext
from matplotlib import cm
import matplotlib.patheffects as path_effects

# %%
with open(r"Sheff Utd_Leeds.json") as f:
    md = json.load(f)

# %%
# 29571

# %%
df = json_normalize(md["events"], sep="_")

# %%
mask = df['playerId'] == 29571
df = df.loc[mask]

# %%
with open('Sheff Utd_Leeds.json') as json_file:
    data = json.load(json_file)

event = []
minute = []
second = []
player = []
team = []
outcome = []
x = []
y = []
endX = []
endY = []
goal = []
passtype = []


for each in data['events']:
    event.append(each['type']['displayName'])
    try:
        minute.append(each['minute'])
    except:
        minute.append('')
    try:
        second.append(each['second'])
    except:
        second.append('')
    try:
        player.append(each['playerId'])
    except:
        player.append('')
    try:
        team.append(each['teamId'])
    except:
        team.append('')
    try:
        endX.append(each['endX'])
        endY.append(each['endY'])
    except:
        endX.append('')
        endY.append('')
    outcome.append(each['outcomeType']['displayName'])
    x.append(each['x'])
    y.append(each['y'])

    for key, value in each.items():
        passType = 'OpenPlay'
        if key == 'qualifiers':
            for item in value:
                if item['type']['displayName'] == 'IntentionalGoalAssist':
                    passType = item['type']['displayName']
                elif item['type']['displayName'] == 'BigChanceCreated':
                    passType = item['type']['displayName']
                elif item['type']['displayName'] == 'Assisted':
                    passType = item['type']['displayName']
            passtype.append(passType)
                
events = pd.DataFrame({'Event':event, 'Minute':minute, 'Second':second, 'Player':player, 'Team':team, 'Outcome':outcome, 'x':x, 'y':y,
                      'endX':endX, 'endY':endY, 'passtype':passtype})

# %%
mask = events['Player'] == 29571
pablo = events.loc[mask]
pablo.Event.value_counts()
# Out:
# Pass               48
# BallRecovery        8
# BallTouch           3
# TakeOn              2
# BlockedPass         2
# SavedShot           2
# Goal                1
# CornerAwarded       1
# Foul                1
# Clearance           1
# Tackle              1
# SubstitutionOff     1
# Interception        1
# Name: Event, dtype: int64

# %%
mask2 = (pablo['Event'] == 'Pass') & (pablo['Outcome'] == 'Successful') 
passed = pablo.loc[mask2]
passed.head()
# Out:
#     Event  Minute Second Player  Team     Outcome     x     y  endX  endY  \
# 37   Pass       1     12  29571    19  Successful  55.7  35.8  80.8  18.6
# 91   Pass       4      2  29571    19  Successful  28.7  12.3  43.2  33.1
# 112  Pass       4     52  29571    19  Successful  32.3  47.2    48  52.1
# 117  Pass       5      7  29571    19  Successful  77.8   9.2  79.1    17
# 213  Pass      10     40  29571    19  Successful  39.5  10.9  54.5  42.4
#
#      passtype
# 37   OpenPlay
# 91   OpenPlay
# 112  OpenPlay
# 117  OpenPlay
# 213  OpenPlay

# %%
mask2 = (pablo['Event'] == 'Pass') & (pablo['Outcome'] == 'Unsuccessful') 
unpassed = pablo.loc[mask2]
unpassed.head()
# Out:
#     Event  Minute Second Player  Team       Outcome     x     y  endX  endY  \
# 280  Pass      14     21  29571    19  Unsuccessful  73.2  12.2  74.9  16.1
# 375  Pass      23      1  29571    19  Unsuccessful  29.5  27.3  29.2  38.9
# 419  Pass      25     45  29571    19  Unsuccessful  99.5  99.5   100  26.1
# 442  Pass      27     30  29571    19  Unsuccessful  64.8   7.6  74.1  10.7
# 586  Pass      36     23  29571    19  Unsuccessful  73.6  43.5  73.9  50.1
#
#      passtype
# 280  OpenPlay
# 375  OpenPlay
# 419  OpenPlay
# 442  OpenPlay
# 586  OpenPlay

# %%
mask3 = (pablo['Event'] == 'MissedShots') | (pablo['Event'] == 'SavedShot')
shot = pablo.loc[mask3]
shot
# Out:
#           Event  Minute Second Player  Team     Outcome     x     y endX endY  \
# 530   SavedShot      33     18  29571    19  Successful  79.9  67.4
# 1408  SavedShot      87     41  29571    19  Successful  75.6  49.9
#
#       passtype
# 530   OpenPlay
# 1408  OpenPlay

# %%
mask4 = pablo['Event'] == 'Goal'
goals = pablo.loc[mask4]
goals
# Out:
#      Event  Minute Second Player  Team     Outcome     x     y endX endY  \
# 1316  Goal      81      3  29571    19  Successful  90.9  47.3
#
#       passtype
# 1316  Assisted

# %%
background = "#313332"
line = '#696969'
text_color ='white'
touches = '#f62681'
assisted = "#45c7e8"
goal = '#59c08a'
title_font = "BBC Reith Sans"
body_font = "BBC Reith Sans"

pitch = Pitch(figsize=(15,15),orientation='horizontal',view='full',goal_type='box',pitch_type='opta',
              pitch_color=background, line_color=line,constrained_layout=False)

fig, ax = pitch.draw()

style="wedge,tail_width=0.4"

#successful
xA = passed.x.values
yA = passed.y.values
xEA = passed.endX.values
yEA = passed.endY.values

for i in range(len(passed)):
    plt.annotate('', xy=(xA[i],yA[i]), xytext=(xEA[i],yEA[i]), zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='#45c7e8', shrinkA=6, alpha=0.4))

#unsuccessful
xC = unpassed.x.values
yC = unpassed.y.values
xEC = unpassed.endX.values
yEC = unpassed.endY.values

for i in range(len(unpassed)):
    plt.annotate('', xy=(xC[i],yC[i]), xytext=(xEC[i],yEC[i]), zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=0.5,  color='darkgrey', shrinkA=6, alpha=0.2))
    
#shots
xS = shot.x.values
yS = shot.y.values

plt.scatter(xS,yS,color=background, ec=goal, lw=1.5, s=130, zorder=11, alpha=0.6)

#goals
xG = goals.x.values
yG = goals.y.values
plt.scatter(xG,yG,color=goal, ec=background, lw=1, s=150, zorder=13, alpha=0.9)

fig.text(0.035, 0.83, "Pablo Hernández",fontsize=30, fontfamily=body_font, color=text_color, weight='bold',zorder=2)
fig.text(0.035, 0.81, "vs Sheffield United | English Championship 2018/19 | Sat 01 Dec 2018",fontsize=15, fontfamily=body_font, color=text_color,zorder=2)

ax4 = fig.add_axes([0.2,0.17,0.05,0.02])
ax4.axis("off")
ax4.scatter([0.2],[0.05],ec=goal, c=background, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.236, 0.175, "shot",fontsize=15, fontfamily=body_font, color=text_color)

ax5 = fig.add_axes([0.316,0.17,0.05,0.02])
ax5.axis("off")
ax5.scatter([0.316],[0.05],c=goal, s=200, linewidth=2, zorder=12, alpha=0.9)
fig.text(0.353, 0.175, "goal",fontsize=15, fontfamily=body_font, color=text_color)

ax6 = fig.add_axes([0.42,0.17,0.05,0.02])
ax6.axis("off")
ax6.annotate('', [0.42,0.5],[1.5,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color=assisted, shrinkA=6, alpha=0.6))

fig.text(0.495, 0.175, "successful pass",fontsize=15, fontfamily=body_font, color=text_color)

ax8 = fig.add_axes([0.63,0.17,0.05,0.02])
ax8.axis("off")
ax8.annotate('', [0.63,0.5],[1.8,0.5], zorder=7, arrowprops=dict(arrowstyle=style,
            linewidth=2,  color='darkgrey', shrinkA=6, alpha=0.6))

fig.text(0.72, 0.175, "unsuccessful pass",fontsize=15, fontfamily=body_font, color=text_color)

plt.rcParams['axes.facecolor']=background
plt.rcParams['savefig.facecolor']=background
plt.savefig("pablo",bbox_inches="tight",dpi=300);

# %%
events.Event.value_counts()
# Out:
# Pass               931
# BallRecovery       107
# BallTouch           72
# Aerial              68
# Clearance           53
# Foul                46
# Tackle              30
# Interception        25
# CornerAwarded       24
# TakeOn              23
# BlockedPass         22
# Dispossessed        21
# MissedShots         12
# Save                 9
# Challenge            9
# SavedShot            9
# Card                 7
# End                  6
# KeeperPickup         6
# SubstitutionOn       5
# SubstitutionOff      5
# Start                4
# FormationChange      4
# OffsidePass          3
# OffsideGiven         3
# OffsideProvoked      3
# Punch                3
# FormationSet         2
# Error                2
# ShotOnPost           1
# Goal                 1
# Name: Event, dtype: int64

# %%
mask = (events['Team'] == 19) & ((events['Event'] == 'BallRecovery') | (events['Event'] == 'Clearance') | (events['Event'] == 'Tackle') | (events['Event'] == 'Interception'))
def_actions = events.loc[mask]
def_actions
# Out:
#              Event  Minute Second  Player  Team     Outcome     x     y  endX  \
# 23    BallRecovery       0     43   42637    19  Successful  28.8  96.0
# 35    BallRecovery       1      9  134143    19  Successful  35.9  27.0
# 51    BallRecovery       2      0  270446    19  Successful  23.8   8.0
# 62    BallRecovery       2     23   82972    19  Successful  41.5  63.6
# 74    BallRecovery       3     21   82972    19  Successful  37.1  17.0
# ...            ...     ...    ...     ...   ...         ...   ...   ...   ...
# 1475     Clearance      91     38  134143    19  Successful   3.4  43.9   7.8
# 1477     Clearance      91     41  134143    19  Successful   5.2  47.9  10.2
# 1498     Clearance      93     11  121123    19  Successful  11.9  46.9  24.6
# 1502     Clearance      93     27  134143    19  Successful   4.3  17.2   4.3
# 1506     Clearance      93     47  101634    19  Successful   4.5  40.7  36.1
#
#       endY  passtype
# 23          OpenPlay
# 35          OpenPlay
# 51          OpenPlay
# 62          OpenPlay
# 74          OpenPlay
# ...    ...       ...
# 1475  52.8  OpenPlay
# 1477  46.6  OpenPlay
# 1498     0  OpenPlay
# 1502  17.2  OpenPlay
# 1506  45.4  OpenPlay
#
# [118 rows x 11 columns]

# %%
csfont = {'fontname':'BBC Reith Sans'}
hfont = {'fontname':'BBC Reith Sans'}
pitch = Pitch(figsize=(10,10),orientation='horizontal',view='full',goal_type='box',pitch_type='opta',
              pitch_color=background, line_color=line,constrained_layout=False)

fig, ax = pitch.draw()
plt.scatter(def_actions['x'],def_actions['y'],color='FFCD00', s=150, zorder=12,alpha=0.7, ec=background,lw=1.5)

x = def_actions['x']
plt.hist(x, bins = 3,rwidth=0.97, color='lightblue',alpha=0.15)

fig.text(0.035, 0.83, "Leeds United Defensive Actions",fontsize=30, fontfamily=body_font, color=text_color, weight='bold',zorder=2, **csfont)
fig.text(0.035, 0.81, "vs Sheffield United | English Championship 2018/19 | Sat 01 Dec 2018",fontsize=15, fontfamily=body_font, color=text_color,zorder=2, **csfont)
info_string = '@jonollington'
plt.text(93, -3, info_string, color='#ffffff', ha='left', va='bottom', fontsize=9, **csfont)

plt.rcParams['axes.facecolor']=background
plt.rcParams['savefig.facecolor']=background
plt.savefig("leeds def actions",bbox_inches="tight",dpi=200);
