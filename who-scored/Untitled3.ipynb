# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from pandas import json_normalize


from adjustText import adjust_text
from matplotlib import cm
import matplotlib.patheffects as path_effects

# %%
with open(r"Fulham_Arsenal.json") as f:
    md = json.load(f)

# %%
side = "home" if md["home"]["name"] == "Arsenal" else "away"  
team_id = md[side]["teamId"]

# %%
df = json_normalize(md["events"], sep="_")

# %%
df
# Out:
#       eventId  expandedMinute          id  isTouch  minute  \
# 0           2               0  2210244067    False       0
# 1           2               0  2210244065    False       0
# 2           3               0  2210244073     True       0
# 3           4               0  2210244081     True       0
# 4           5               0  2210244095     True       0
# ...       ...             ...         ...      ...     ...
# 1643      926              94  2210272807    False      92
# 1644      927               4  2210272901    False       0
# 1645      819               4  2210273175    False       0
# 1646        1               0  2210228675    False       0
# 1647        1               0  2210228697    False       0
#
#                                              qualifiers  \
# 0                                                    []
# 1                                                    []
# 2     [{'type': {'displayName': 'Angle', 'value': 21...
# 3     [{'type': {'displayName': 'PassEndX', 'value':...
# 4     [{'type': {'displayName': 'Length', 'value': 2...
# ...                                                 ...
# 1643                                                 []
# 1644                                                 []
# 1645                                                 []
# 1646  [{'type': {'displayName': 'TeamFormation', 'va...
# 1647  [{'type': {'displayName': 'CaptainPlayerId', '...
#
#                  satisfiedEventsTypes  second  teamId     x  ...  satisfiers  \
# 0                                  []     0.0      13   0.0  ...         NaN
# 1                                  []     0.0     170   0.0  ...         NaN
# 2     [90, 116, 29, 34, 36, 215, 217]     0.0     170  49.9  ...         NaN
# 3     [90, 116, 29, 34, 36, 215, 217]     1.0     170  37.3  ...         NaN
# 4     [90, 116, 29, 34, 37, 214, 217]     3.0     170  35.3  ...         NaN
# ...                               ...     ...     ...   ...  ...         ...
# 1643                               []    58.0      13   0.0  ...         NaN
# 1644                               []     0.0      13   0.0  ...         NaN
# 1645                               []     0.0     170   0.0  ...         NaN
# 1646                               []     0.0     170   0.0  ...         NaN
# 1647                               []     0.0      13   0.0  ...         NaN
#
#      text  minuteInfo_expandedMinute minuteInfo_extraTime  \
# 0     NaN                        NaN                  NaN
# 1     NaN                        NaN                  NaN
# 2     NaN                        NaN                  NaN
# 3     NaN                        NaN                  NaN
# 4     NaN                        NaN                  NaN
# ...   ...                        ...                  ...
# 1643  NaN                        NaN                  NaN
# 1644  NaN                        NaN                  NaN
# 1645  NaN                        NaN                  NaN
# 1646  NaN                        NaN                  NaN
# 1647  NaN                        NaN                  NaN
#
#       minuteInfo_isEndOfPeriod minuteInfo_minute  minuteInfo_minuteString  \
# 0                          NaN               NaN                      NaN
# 1                          NaN               NaN                      NaN
# 2                          NaN               NaN                      NaN
# 3                          NaN               NaN                      NaN
# 4                          NaN               NaN                      NaN
# ...                        ...               ...                      ...
# 1643                       NaN               NaN                      NaN
# 1644                       NaN               NaN                      NaN
# 1645                       NaN               NaN                      NaN
# 1646                       NaN               NaN                      NaN
# 1647                       NaN               NaN                      NaN
#
#       minuteInfo_period  type_$idx  type_$len
# 0                   NaN        NaN        NaN
# 1                   NaN        NaN        NaN
# 2                   NaN        NaN        NaN
# 3                   NaN        NaN        NaN
# 4                   NaN        NaN        NaN
# ...                 ...        ...        ...
# 1643                NaN        NaN        NaN
# 1644                NaN        NaN        NaN
# 1645                NaN        NaN        NaN
# 1646                NaN        NaN        NaN
# 1647                NaN        NaN        NaN
#
# [1648 rows x 43 columns]
