# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

# %%
page = "https://www.transfermarkt.co.uk/arsenal-fc/kader/verein/11/saison_id/2019/plus/1"
pageTree = requests.get(page, headers=headers)
pageSoup = BeautifulSoup(pageTree.content, 'html.parser')

# %%
players = pageSoup.findAll("a", {"class" : "spielprofil_tooltip"})
[(player.getText(), player.attrs['href']) for player in players]
# Out:
# [('Bernd Leno', '/bernd-leno/profil/spieler/72476'),
#  ('B. Leno', '/bernd-leno/profil/spieler/72476'),
#  ('Emiliano Martínez', '/emiliano-martinez/profil/spieler/111873'),
#  ('E. Martínez', '/emiliano-martinez/profil/spieler/111873'),
#  ('Matt Macey', '/matt-macey/profil/spieler/220491'),
#  ('M. Macey', '/matt-macey/profil/spieler/220491'),
#  ('William Saliba', '/william-saliba/profil/spieler/495666'),
#  ('W. Saliba', '/william-saliba/profil/spieler/495666'),
#  ('Sokratis', '/sokratis/profil/spieler/34322'),
#  ('Sokratis', '/sokratis/profil/spieler/34322'),
#  ('Calum Chambers', '/calum-chambers/profil/spieler/215118'),
#  ('C. Chambers', '/calum-chambers/profil/spieler/215118'),
#  ('Shkodran Mustafi', '/shkodran-mustafi/profil/spieler/88590'),
#  ('S. Mustafi', '/shkodran-mustafi/profil/spieler/88590'),
#  ('David Luiz', '/david-luiz/profil/spieler/46741'),
#  ('David Luiz', '/david-luiz/profil/spieler/46741'),
#  ('Rob Holding', '/rob-holding/profil/spieler/253341'),
#  ('R. Holding', '/rob-holding/profil/spieler/253341'),
#  ('Pablo Marí', '/pablo-mari/profil/spieler/210178'),
#  ('P. Marí', '/pablo-mari/profil/spieler/210178'),
#  ('Kieran Tierney', '/kieran-tierney/profil/spieler/300716'),
#  ('K. Tierney', '/kieran-tierney/profil/spieler/300716'),
#  ('Sead Kolasinac', '/sead-kolasinac/profil/spieler/94005'),
#  ('S. Kolasinac', '/sead-kolasinac/profil/spieler/94005'),
#  ('Héctor Bellerín', '/hector-bellerin/profil/spieler/191217'),
#  ('H. Bellerín', '/hector-bellerin/profil/spieler/191217'),
#  ('Ainsley Maitland-Niles', '/ainsley-maitland-niles/profil/spieler/285845'),
#  ('A. Maitland-Niles', '/ainsley-maitland-niles/profil/spieler/285845'),
#  ('Cédric Soares', '/cedric-soares/profil/spieler/112988'),
#  ('C. Soares', '/cedric-soares/profil/spieler/112988'),
#  ('Lucas Torreira', '/lucas-torreira/profil/spieler/318077'),
#  ('L. Torreira', '/lucas-torreira/profil/spieler/318077'),
#  ('Granit Xhaka', '/granit-xhaka/profil/spieler/111455'),
#  ('G. Xhaka', '/granit-xhaka/profil/spieler/111455'),
#  ('Mattéo Guendouzi', '/matteo-guendouzi/profil/spieler/465830'),
#  ('M. Guendouzi', '/matteo-guendouzi/profil/spieler/465830'),
#  ('Dani Ceballos', '/dani-ceballos/profil/spieler/319745'),
#  ('D. Ceballos', '/dani-ceballos/profil/spieler/319745'),
#  ('Joe Willock', '/joe-willock/profil/spieler/340329'),
#  ('J. Willock', '/joe-willock/profil/spieler/340329'),
#  ('Mesut Özil', '/mesut-ozil/profil/spieler/35664'),
#  ('M. Özil', '/mesut-ozil/profil/spieler/35664'),
#  ('Gabriel Martinelli', '/gabriel-martinelli/profil/spieler/655488'),
#  ('G. Martinelli', '/gabriel-martinelli/profil/spieler/655488'),
#  ('Bukayo Saka', '/bukayo-saka/profil/spieler/433177'),
#  ('B. Saka', '/bukayo-saka/profil/spieler/433177'),
#  ('Nicolas Pépé', '/nicolas-pepe/profil/spieler/343052'),
#  ('N. Pépé', '/nicolas-pepe/profil/spieler/343052'),
#  ('Reiss Nelson', '/reiss-nelson/profil/spieler/340325'),
#  ('R. Nelson', '/reiss-nelson/profil/spieler/340325'),
#  ('Pierre-Emerick Aubameyang',
#   '/pierre-emerick-aubameyang/profil/spieler/58864'),
#  ('P. Aubameyang', '/pierre-emerick-aubameyang/profil/spieler/58864'),
#  ('Alexandre Lacazette', '/alexandre-lacazette/profil/spieler/93720'),
#  ('A. Lacazette', '/alexandre-lacazette/profil/spieler/93720'),
#  ('Eddie Nketiah', '/eddie-nketiah/profil/spieler/340324'),
#  ('E. Nketiah', '/eddie-nketiah/profil/spieler/340324')]

# %%
#Process each of the players lists into text-only lists
PlayersText = []
for player in Players:
    PlayersText.append(player.text)

# %%
PlayersText
# Out:
# ['Bernd Leno',
#  'B. Leno',
#  'Emiliano Martínez',
#  'E. Martínez',
#  'Matt Macey',
#  'M. Macey',
#  'William Saliba',
#  'W. Saliba',
#  'Sokratis',
#  'Sokratis',
#  'Calum Chambers',
#  'C. Chambers',
#  'Shkodran Mustafi',
#  'S. Mustafi',
#  'David Luiz',
#  'David Luiz',
#  'Rob Holding',
#  'R. Holding',
#  'Pablo Marí',
#  'P. Marí',
#  'Kieran Tierney',
#  'K. Tierney',
#  'Sead Kolasinac',
#  'S. Kolasinac',
#  'Héctor Bellerín',
#  'H. Bellerín',
#  'Ainsley Maitland-Niles',
#  'A. Maitland-Niles',
#  'Cédric Soares',
#  'C. Soares',
#  'Lucas Torreira',
#  'L. Torreira',
#  'Granit Xhaka',
#  'G. Xhaka',
#  'Mattéo Guendouzi',
#  'M. Guendouzi',
#  'Dani Ceballos',
#  'D. Ceballos',
#  'Joe Willock',
#  'J. Willock',
#  'Mesut Özil',
#  'M. Özil',
#  'Gabriel Martinelli',
#  'G. Martinelli',
#  'Bukayo Saka',
#  'B. Saka',
#  'Nicolas Pépé',
#  'N. Pépé',
#  'Reiss Nelson',
#  'R. Nelson',
#  'Pierre-Emerick Aubameyang',
#  'P. Aubameyang',
#  'Alexandre Lacazette',
#  'A. Lacazette',
#  'Eddie Nketiah',
#  'E. Nketiah']

# %%
player=[player for player in PlayersText][::2]

# %%
signed_from = pageSoup.findAll("a", {"class" : "vereinprofil_tooltip"})
signed_from_data = [(sign.img.attrs['alt'], sign.img.attrs['title']) for sign in signed_from ]

# %%
signed_from_data
# Out:
# [('Bayer 04 Leverkusen', ': Ablöse £22.50m'),
#  ('Arsenal FC U21', ': Ablöse -'),
#  ('Arsenal FC U21', ': Ablöse -'),
#  ('AS Saint-Étienne', ': Ablöse £27.00m'),
#  ('Borussia Dortmund', ': Ablöse £14.40m'),
#  ('Southampton FC', ': Ablöse £18.21m'),
#  ('Valencia CF', ': Ablöse £36.90m'),
#  ('Chelsea FC', ': Ablöse £7.83m'),
#  ('Bolton Wanderers', ': Ablöse £2.70m'),
#  ('Clube de Regatas do Flamengo', ': Ablöse £7.20m'),
#  ('Celtic FC', ': Ablöse £24.30m'),
#  ('FC Schalke 04', ': Ablöse Free transfer'),
#  ('Arsenal FC U21', ': Ablöse -'),
#  ('Arsenal FC U23', ': Ablöse -'),
#  ('Southampton FC', ': Ablöse Free transfer'),
#  ('UC Sampdoria', ': Ablöse £25.79m'),
#  ('Borussia Mönchengladbach', ': Ablöse £40.50m'),
#  ('FC Lorient', ': Ablöse £7.20m'),
#  ('Real Madrid', ': Ablöse ?'),
#  ('Arsenal FC U23', ': Ablöse -'),
#  ('Real Madrid', ': Ablöse £42.30m'),
#  ('Ituano Futebol Clube (SP)', ': Ablöse £6.03m'),
#  ('Arsenal FC U23', ': Ablöse -'),
#  ('LOSC Lille', ': Ablöse £72.00m'),
#  ('Arsenal FC U23', ': Ablöse -'),
#  ('Borussia Dortmund', ': Ablöse £57.38m'),
#  ('Olympique Lyon', ': Ablöse £47.70m'),
#  ('Arsenal FC U23', ': Ablöse -')]

# %%
signed_from_text = []
for team in signed_from_data:
    signed_from_text.append(team[:][0])

# %%
signed_from_text
# Out:
# ['Bayer 04 Leverkusen',
#  'Arsenal FC U21',
#  'Arsenal FC U21',
#  'AS Saint-Étienne',
#  'Borussia Dortmund',
#  'Southampton FC',
#  'Valencia CF',
#  'Chelsea FC',
#  'Bolton Wanderers',
#  'Clube de Regatas do Flamengo',
#  'Celtic FC',
#  'FC Schalke 04',
#  'Arsenal FC U21',
#  'Arsenal FC U23',
#  'Southampton FC',
#  'UC Sampdoria',
#  'Borussia Mönchengladbach',
#  'FC Lorient',
#  'Real Madrid',
#  'Arsenal FC U23',
#  'Real Madrid',
#  'Ituano Futebol Clube (SP)',
#  'Arsenal FC U23',
#  'LOSC Lille',
#  'Arsenal FC U23',
#  'Borussia Dortmund',
#  'Olympique Lyon',
#  'Arsenal FC U23']

# %%
#Put into a dataframe and check it out
data = pd.DataFrame({'player':player,'sign_from':signed_from_text})
data
# Out:
#                        player                     sign_from
# 0                  Bernd Leno           Bayer 04 Leverkusen
# 1           Emiliano Martínez                Arsenal FC U21
# 2                  Matt Macey                Arsenal FC U21
# 3              William Saliba              AS Saint-Étienne
# 4                    Sokratis             Borussia Dortmund
# 5              Calum Chambers                Southampton FC
# 6            Shkodran Mustafi                   Valencia CF
# 7                  David Luiz                    Chelsea FC
# 8                 Rob Holding              Bolton Wanderers
# 9                  Pablo Marí  Clube de Regatas do Flamengo
# 10             Kieran Tierney                     Celtic FC
# 11             Sead Kolasinac                 FC Schalke 04
# 12            Héctor Bellerín                Arsenal FC U21
# 13     Ainsley Maitland-Niles                Arsenal FC U23
# 14              Cédric Soares                Southampton FC
# 15             Lucas Torreira                  UC Sampdoria
# 16               Granit Xhaka      Borussia Mönchengladbach
# 17           Mattéo Guendouzi                    FC Lorient
# 18              Dani Ceballos                   Real Madrid
# 19                Joe Willock                Arsenal FC U23
# 20                 Mesut Özil                   Real Madrid
# 21         Gabriel Martinelli     Ituano Futebol Clube (SP)
# 22                Bukayo Saka                Arsenal FC U23
# 23               Nicolas Pépé                    LOSC Lille
# 24               Reiss Nelson                Arsenal FC U23
# 25  Pierre-Emerick Aubameyang             Borussia Dortmund
# 26        Alexandre Lacazette                Olympique Lyon
# 27              Eddie Nketiah                Arsenal FC U23

# %%
# Save dataframe
data.to_csv('EFL-FWD-Radar_df.csv', index=False)
